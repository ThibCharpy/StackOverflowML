# %%
import urllib.request
import re

# %%
def get_questions_from_page(url):
    """
    Extracts blocks of HTML which correspond to questions on the page.
    
    Args: 
        url (str): url of a page
    
    Returns: 
        (list of str): list of html contents of each question
    """
    
    req = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    #print("trying to open", url)
    with urllib.request.urlopen(req) as response:
        html = str(response.read())
        
    print("parsing", url)
    regex_mainbar = "<div id=\"mainbar\">(.*?)<div id=\"sidebar\">"
    match_mainbar = re.search(regex_mainbar, html)
    if match_mainbar:
        html_mainbar = match_mainbar.group(0)
    else:
        print("mainbar not found")
    
    # Each question is inside a <div> with a class "summary"
    # Splitting the text by div title, we get N+1 elements:
    # 0:  html before the first question
    # 1..N:  html of all the N questions
    regex_question = "<div class=\"summary\">"
    list_html_questions = re.split(regex_question, html_mainbar)[1:]
    #print(len(list_html_questions), "questions found")
    return list_html_questions

# %%
def get_tags_from_question(html_question):
    """
    Extracts the list of tags from a question HTML.
    
    Args:
        html_question (str): HTML code of a question
    Returns:
        (list of str): list of tags as strings
    """
    regex_tags = "\/questions\/tagged\/(.*?)\""
    tags = re.findall(regex_tags, html_question)
    return [decode_url(tag) for tag in tags]

# %%
def decode_url(url):
    decode_url = {}
    decode_url["%23"] = "#"
    decode_url["%2b"] = "+"
    for key in decode_url:
        if key in url:
            url = url.replace(key, decode_url[key])
    return url

# %%
def extract_cooccurrences(cooccur_dict):
    """
    Args:
        cooccur_dict (dict of {tag_id (str): nb_of_cooccur (int)} dicts)
    Returns:
        tuples (tag1_idx, tag2_idx, nb_of_cooccurrences)
    """
    cooccur_tuples = []
    for tag1_idx in cooccur_dict:
        for tag2_idx in cooccur_dict[tag1_idx]:
            # De-duplicating
            if tag1_idx < tag2_idx:
                smaller_idx = tag1_idx
                bigger_idx = tag2_idx
            else:
                smaller_idx = tag2_idx
                bigger_idx = tag1_idx
            t = (smaller_idx, bigger_idx, cooccur_dict[tag1_idx][tag2_idx])
            if t not in cooccur_tuples:
                cooccur_tuples.append(t)
    return cooccur_tuples

# %%
def serialize(obj, path):
    with open(path, 'w') as out_file:
        out_file.write(str(obj))
    print('File', path, 'written.')

# %%
def calculate_pairs(all_tags, cooccur_dict):
    cooccur_tuples = extract_cooccurrences(cooccur_dict)
    # Sort tuples by number of cooccurences
    cooccur_tuples.sort(key=lambda tup: tup[2], reverse=True)
    pairs = []
    for tup in cooccur_tuples[:100]:
        tag1 = all_tags[int(tup[0])] 
        tag2 = all_tags[int(tup[1])] 
        pairs.append((tag1, tag2, tup[2]))
    return pairs

# %%
# List of all tag names
all_tags = []

# Dictionary that counts total occurences of each tag
# Example {"3": 16, "17": 8}, 
#         where "3" is the code of "java", "17" is the code of "python"
tags_counts = {}

# Each tag has a co-occurrence dictionary in the form {index_of_related_tag: number_of_cooccurrences, ...}
# Meta-dictionary of a form {tag: coappearance_dictionary}
# Example: {"3": {"5": 1, "17": 4},    "5": {"3": 1, "4": 33, "9": 15}, ... } ,
#     where "3" - the code of "java", "5" - "javascript",  "17" - "python".
cooccur_dict = {}

MAX_PAGE_INDEX = 10000 #669683   #201030 for 50 questions per page
SERIALIZE_EVERY_N_PAGES = 1000

for page_index in range(1, MAX_PAGE_INDEX+1):
    #url = "http://stackoverflow.com/questions?page=" + str(page_index) + "&sort=newest"
    url = "http://stackoverflow.com/questions?pagesize=50&page=" + str(page_index) + "&sort=newest"
    questions = get_questions_from_page(url)
    for html_question in questions:
        tags = get_tags_from_question(html_question)
        #print(tags)
        
        # 1. Looping through each tag, adding new tags to list, adding 1 to tag's occurence count
        for tag in tags:
            if tag not in all_tags:
                all_tags.append(tag)
            tag_index = str(all_tags.index(tag))
            if tag_index in tags_counts:
                tags_counts[tag_index] += 1
            else:
                tags_counts[tag_index] = 1
                
        # 2. Looping through all PAIRS of tags in question, calculating co-occurrence    
        for tag1_idx_in_question in range(len(tags)):
            tag1_text = tags[tag1_idx_in_question]
            tag1_index = str(all_tags.index(tag1_text))
            if tag1_index not in cooccur_dict:
                cooccur_dict[tag1_index] = {}
            
            for tag2_idx_in_question in range(len(tags)):
                if tag2_idx_in_question == tag1_idx_in_question:
                    continue
                tag2_text = tags[tag2_idx_in_question]
                tag2_index = str(all_tags.index(tag2_text))
                # If there already was a coappearances between these 2 tags yet, increment count by 1.
                # Otherwise, create this coappearance with count 1.
                if tag2_index in cooccur_dict[tag1_index]:
                    cooccur_dict[tag1_index][tag2_index] += 1
                else:
                    cooccur_dict[tag1_index][tag2_index] = 1
    
    # Serializing results
    if page_index > 0 and page_index % SERIALIZE_EVERY_N_PAGES == 0:
        pairs = calculate_pairs(all_tags, cooccur_dict)
        #serialize(all_tags, 'results/{0}_all_tags.txt'.format(page_index))
        #serialize(tags_counts, 'results/{0}_tags_counts.txt'.format(page_index))
        #serialize(cooccur_dict, 'results/{0}_cooccur_dict.txt'.format(page_index))
        serialize(pairs, 'results/{0}_pairs.txt'.format(page_index))
        
        
# a) 15 questions per page:  37 sec for 100 p./1500 quest.
#       ====> about 10,000 p./150,000 quest. per hour 
#       =====> about 66 hours to parse all of 10M questions (669683 pages)
# b) 50 questions per page:  55 seconds for 100 p./5000 quest.
#       ====> approximately 6,000 pages/300,000 questions per hour  
#        =====> about 33 hours to parse 10M questions (201030 pages)
# Out:
# parsing http://stackoverflow.com/questions?pagesize=50&page=1&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=2&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=3&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=4&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=5&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=6&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=7&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=8&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=9&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=10&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=11&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=12&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=13&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=14&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=15&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=16&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=17&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=18&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=19&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=20&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=21&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=22&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=23&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=24&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=25&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=26&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=27&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=28&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=29&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=30&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=31&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=32&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=33&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=34&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=35&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=36&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=37&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=38&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=39&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=40&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=41&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=42&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=43&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=44&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=45&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=46&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=47&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=48&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=49&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=50&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=51&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=52&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=53&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=54&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=55&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=56&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=57&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=58&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=59&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=60&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=61&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=62&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=63&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=64&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=65&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=66&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=67&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=68&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=69&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=70&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=71&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=72&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=73&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=74&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=75&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=76&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=77&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=78&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=79&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=80&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=81&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=82&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=83&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=84&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=85&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=86&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=87&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=88&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=89&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=90&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=91&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=92&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=93&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=94&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=95&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=96&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=97&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=98&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=99&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=100&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=101&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=102&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=103&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=104&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=105&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=106&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=107&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=108&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=109&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=110&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=111&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=112&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=113&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=114&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=115&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=116&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=117&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=118&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=119&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=120&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=121&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=122&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=123&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=124&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=125&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=126&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=127&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=128&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=129&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=130&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=131&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=132&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=133&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=134&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=135&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=136&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=137&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=138&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=139&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=140&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=141&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=142&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=143&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=144&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=145&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=146&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=147&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=148&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=149&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=150&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=151&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=152&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=153&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=154&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=155&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=156&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=157&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=158&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=159&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=160&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=161&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=162&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=163&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=164&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=165&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=166&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=167&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=168&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=169&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=170&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=171&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=172&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=173&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=174&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=175&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=176&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=177&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=178&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=179&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=180&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=181&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=182&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=183&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=184&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=185&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=186&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=187&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=188&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=189&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=190&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=191&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=192&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=193&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=194&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=195&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=196&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=197&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=198&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=199&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=200&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=201&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=202&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=203&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=204&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=205&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=206&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=207&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=208&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=209&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=210&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=211&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=212&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=213&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=214&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=215&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=216&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=217&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=218&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=219&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=220&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=221&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=222&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=223&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=224&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=225&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=226&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=227&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=228&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=229&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=230&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=231&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=232&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=233&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=234&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=235&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=236&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=237&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=238&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=239&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=240&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=241&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=242&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=243&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=244&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=245&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=246&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=247&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=248&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=249&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=250&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=251&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=252&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=253&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=254&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=255&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=256&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=257&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=258&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=259&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=260&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=261&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=262&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=263&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=264&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=265&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=266&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=267&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=268&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=269&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=270&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=271&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=272&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=273&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=274&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=275&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=276&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=277&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=278&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=279&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=280&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=281&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=282&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=283&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=284&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=285&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=286&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=287&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=288&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=289&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=290&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=291&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=292&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=293&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=294&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=295&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=296&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=297&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=298&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=299&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=300&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=301&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=302&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=303&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=304&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=305&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=306&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=307&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=308&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=309&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=310&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=311&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=312&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=313&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=314&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=315&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=316&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=317&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=318&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=319&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=320&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=321&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=322&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=323&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=324&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=325&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=326&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=327&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=328&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=329&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=330&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=331&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=332&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=333&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=334&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=335&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=336&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=337&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=338&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=339&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=340&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=341&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=342&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=343&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=344&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=345&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=346&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=347&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=348&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=349&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=350&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=351&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=352&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=353&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=354&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=355&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=356&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=357&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=358&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=359&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=360&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=361&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=362&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=363&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=364&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=365&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=366&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=367&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=368&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=369&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=370&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=371&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=372&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=373&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=374&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=375&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=376&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=377&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=378&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=379&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=380&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=381&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=382&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=383&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=384&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=385&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=386&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=387&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=388&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=389&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=390&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=391&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=392&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=393&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=394&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=395&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=396&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=397&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=398&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=399&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=400&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=401&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=402&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=403&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=404&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=405&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=406&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=407&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=408&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=409&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=410&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=411&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=412&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=413&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=414&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=415&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=416&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=417&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=418&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=419&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=420&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=421&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=422&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=423&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=424&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=425&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=426&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=427&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=428&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=429&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=430&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=431&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=432&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=433&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=434&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=435&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=436&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=437&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=438&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=439&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=440&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=441&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=442&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=443&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=444&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=445&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=446&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=447&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=448&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=449&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=450&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=451&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=452&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=453&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=454&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=455&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=456&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=457&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=458&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=459&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=460&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=461&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=462&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=463&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=464&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=465&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=466&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=467&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=468&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=469&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=470&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=471&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=472&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=473&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=474&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=475&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=476&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=477&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=478&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=479&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=480&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=481&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=482&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=483&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=484&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=485&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=486&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=487&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=488&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=489&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=490&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=491&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=492&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=493&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=494&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=495&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=496&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=497&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=498&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=499&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=500&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=501&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=502&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=503&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=504&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=505&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=506&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=507&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=508&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=509&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=510&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=511&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=512&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=513&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=514&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=515&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=516&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=517&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=518&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=519&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=520&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=521&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=522&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=523&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=524&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=525&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=526&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=527&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=528&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=529&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=530&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=531&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=532&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=533&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=534&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=535&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=536&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=537&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=538&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=539&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=540&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=541&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=542&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=543&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=544&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=545&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=546&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=547&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=548&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=549&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=550&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=551&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=552&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=553&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=554&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=555&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=556&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=557&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=558&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=559&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=560&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=561&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=562&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=563&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=564&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=565&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=566&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=567&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=568&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=569&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=570&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=571&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=572&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=573&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=574&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=575&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=576&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=577&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=578&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=579&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=580&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=581&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=582&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=583&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=584&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=585&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=586&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=587&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=588&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=589&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=590&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=591&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=592&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=593&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=594&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=595&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=596&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=597&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=598&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=599&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=600&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=601&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=602&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=603&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=604&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=605&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=606&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=607&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=608&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=609&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=610&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=611&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=612&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=613&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=614&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=615&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=616&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=617&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=618&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=619&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=620&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=621&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=622&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=623&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=624&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=625&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=626&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=627&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=628&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=629&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=630&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=631&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=632&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=633&sort=newest
# ...
# parsing http://stackoverflow.com/questions?pagesize=50&page=1810&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1811&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1812&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1813&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1814&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1815&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1816&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1817&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1818&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1819&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1820&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1821&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1822&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1823&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1824&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1825&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1826&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1827&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1828&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1829&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1830&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1831&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1832&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1833&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1834&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1835&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1836&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1837&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1838&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1839&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1840&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1841&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1842&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1843&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1844&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1845&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1846&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1847&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1848&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1849&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1850&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1851&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1852&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1853&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1854&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1855&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1856&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1857&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1858&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1859&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1860&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1861&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1862&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1863&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1864&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1865&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1866&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1867&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1868&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1869&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1870&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1871&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1872&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1873&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1874&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1875&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1876&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1877&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1878&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1879&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1880&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1881&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1882&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1883&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1884&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1885&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1886&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1887&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1888&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1889&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1890&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1891&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1892&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1893&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1894&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1895&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1896&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1897&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1898&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1899&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1900&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1901&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1902&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1903&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1904&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1905&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1906&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1907&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1908&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1909&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1910&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1911&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1912&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1913&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1914&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1915&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1916&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1917&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1918&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1919&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1920&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1921&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1922&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1923&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1924&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1925&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1926&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1927&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1928&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1929&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1930&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1931&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1932&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1933&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1934&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1935&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1936&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1937&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1938&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1939&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1940&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1941&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1942&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1943&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1944&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1945&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1946&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1947&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1948&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1949&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1950&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1951&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1952&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1953&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1954&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1955&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1956&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1957&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1958&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1959&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1960&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1961&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1962&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1963&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1964&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1965&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1966&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1967&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1968&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1969&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1970&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1971&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1972&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1973&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1974&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1975&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1976&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1977&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1978&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1979&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1980&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1981&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1982&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1983&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1984&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1985&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1986&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1987&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1988&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1989&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1990&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1991&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1992&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1993&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1994&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1995&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1996&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1997&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1998&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=1999&sort=newest
# parsing http://stackoverflow.com/questions?pagesize=50&page=2000&sort=newest
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-cc888d4e804a> in <module>()
#      55     # Serializing results
#      56     if page_index > 0 and page_index % SERIALIZE_EVERY_N_PAGES == 0:
# ---> 57         pairs = calculate_pairs(all_tags, cooccur_dict)
#      58         #serialize(all_tags, 'results/{0}_all_tags.txt'.format(page_index))
#      59         #serialize(tags_counts, 'results/{0}_tags_counts.txt'.format(page_index))
#
# <ipython-input-8-c4fdb154e499> in calculate_pairs(all_tags, cooccur_dict)
#       1 def calculate_pairs(all_tags, cooccur_dict):
# ----> 2     cooccur_tuples = extract_cooccurrences(cooccur_dict)
#       3     # Sort tuples by number of cooccurences
#       4     cooccur_tuples.sort(key=lambda tup: tup[2], reverse=True)
#       5     pairs = []
#
# <ipython-input-5-c8117f719b4e> in extract_cooccurrences(cooccur_dict)
#      16                 smaller_idx = tag2_idx
#      17                 bigger_idx = tag1_idx
# ---> 18             t = (smaller_idx, bigger_idx, cooccur_dict[tag1_idx][tag2_idx])
#      19             if t not in cooccur_tuples:
#      20                 cooccur_tuples.append(t)
#
# KeyboardInterrupt:

# %%
all_tags
# Out:
# ['javascript',
#  'google-spreadsheet',
#  'scrape',
#  'mongodb',
#  'nosql',
#  'couchdb',
#  'sharepoint-2013',
#  'document-management',
#  'jquery',
#  'browser',
#  'passwords',
#  '.post',
#  'sql-server-2008',
#  'ios',
#  'objective-c',
#  'uipopovercontroller',
#  'node.js',
#  'html',
#  'css',
#  'email',
#  'gmail',
#  'marketo',
#  'android',
#  'worklight',
#  'mobilefirst',
#  'worklight-adapters',
#  'mobilefirst-adapters',
#  'c',
#  'algorithm',
#  'mathematical-optimization',
#  'java',
#  'swap',
#  'jestjs',
#  'server',
#  'centos6',
#  'yum',
#  'php',
#  'mysql',
#  'xslt',
#  'orders',
#  'multithreading',
#  'swift',
#  'struct',
#  'mutators',
#  'scala',
#  'routes',
#  'akka',
#  'spray',
#  'akka-http',
#  'eclipse',
#  'spring',
#  'maven',
#  'jboss',
#  'spring-boot',
#  'linux',
#  'shell',
#  'c#',
#  'asp.net',
#  'iframe',
#  'python',
#  'macros',
#  'sql',
#  'visual-studio',
#  'sql-server-2012',
#  'delphi',
#  'notifications',
#  'sails.js',
#  'nsthread',
#  'dispatch',
#  'vagrant',
#  'c++',
#  'visual-studio-2010',
#  'text',
#  'fstream',
#  'regex',
#  'r',
#  'conferencing',
#  'simplecart',
#  'excel',
#  'angularjs',
#  'ionic',
#  'arrays',
#  'cost-based-optimizer',
#  'time',
#  'format',
#  'xcode',
#  'parse.com',
#  'uiimage',
#  'string',
#  'd3.js',
#  'svg',
#  'exception',
#  'dictionary',
#  'casting',
#  'hashmap',
#  'sqlite',
#  'join',
#  'excel-vba',
#  'laravel-routing',
#  'laravel-5.1',
#  'reactjs',
#  'typescript',
#  'react-jsx',
#  'socrata',
#  'soda',
#  'ibeacon',
#  'android-ibeacon',
#  'internet-explorer',
#  'onclick',
#  'html5',
#  'socket.io',
#  'kinect',
#  'depth',
#  'point-clouds',
#  'ruby-on-rails',
#  'nested-forms',
#  'clojure',
#  'function',
#  'while-loop',
#  'compiler-errors',
#  'performance',
#  'selector',
#  'cordova',
#  'ionic-framework',
#  'objective',
#  'ajax',
#  'wordpress',
#  'ios7',
#  'ios8',
#  'cllocationmanager',
#  'testflight',
#  'button',
#  'download',
#  'hibernate',
#  'transactions',
#  'qt',
#  'opencv',
#  'web-crawler',
#  'enums',
#  'arguments',
#  'raw-types',
#  'telerik',
#  'kendo-grid',
#  'scheme',
#  'bash',
#  'terminal',
#  'csv',
#  'combobox',
#  'smalltalk',
#  'pharo',
#  'heroku',
#  'playback',
#  'worker',
#  'procfile',
#  'crash',
#  'garbage-collection',
#  'security',
#  'virtual-machine',
#  'vmware',
#  'rss-reader',
#  'logging',
#  'log4j',
#  'mysqli',
#  'c#-4.0',
#  'visual-c++',
#  'google-app-engine',
#  'google-api',
#  'google-api-client',
#  'google-api-python-client',
#  'android-wear',
#  'android-wear-notification',
#  'relation',
#  'pfobject',
#  'private-key',
#  'cryptographicexception',
#  'ruby',
#  'hadoop',
#  'twitter',
#  'cloudera',
#  'flume',
#  'asynchronous',
#  'generator',
#  'ecmascript-6',
#  'windows',
#  'powershell',
#  'meteor',
#  'console',
#  'console-application',
#  'varnish',
#  'varnish-vcl',
#  'json',
#  'xml',
#  'diameter-protocol',
#  'python-2.7',
#  'unity',
#  'database',
#  'automation',
#  'c++11',
#  'gcc',
#  'auto',
#  'type-deduction',
#  '.net',
#  'vb.net',
#  'postgresql',
#  'pgrouting',
#  'django',
#  'responsive-design',
#  'html5-canvas',
#  'random',
#  'unity3d',
#  'scripting',
#  'unityscript',
#  'spawn',
#  'xrange',
#  'twitter-bootstrap',
#  'modal-dialog',
#  'dataset',
#  'grouping',
#  'aggregate',
#  'attributes',
#  'woocommerce',
#  'variation',
#  'express',
#  'loopbackjs',
#  'sql-server',
#  'sorting',
#  'hybrid',
#  'jframe',
#  'fullscreen',
#  'joptionpane',
#  'jcifs',
#  'wpf',
#  'listbox',
#  'bitmap',
#  'universal-image-loader',
#  'memorycache',
#  'image-load',
#  'data',
#  'structure',
#  'banking',
#  'julia-lang',
#  'uinavigationcontroller',
#  'pop',
#  'testcomplete',
#  'v8',
#  'onchange',
#  'table',
#  'wolfram-mathematica',
#  'css3',
#  'signal-processing',
#  'android-mediaplayer',
#  'audio-recording',
#  'audiotrack',
#  'pseudocode',
#  'wordpress-plugin',
#  'wordpress-theming',
#  'wordpress-mu',
#  'pdf',
#  'session',
#  'durandal-2.0',
#  'codeigniter',
#  'cart',
#  'amazon-web-services',
#  'xts',
#  'rbind',
#  'file-get-contents',
#  'unset',
#  'google-chrome',
#  'diffie-hellman',
#  'internet-explorer-10',
#  'object-oriented-analysis',
#  'swing',
#  'wget',
#  'speech-recognition',
#  'cmusphinx',
#  'filter',
#  'bind',
#  'sync',
#  'dll',
#  'static',
#  'noclassdeffounderror',
#  'view',
#  'django-rest-framework',
#  'iis',
#  'owin',
#  'entity-framework',
#  'asp.net-web-api',
#  'asp.net-web-api2',
#  'xlrd',
#  'devexpress',
#  'pointers',
#  'dynamic',
#  'indirection',
#  'windows-10',
#  'android-intent',
#  'android-activity',
#  'recyclerview',
#  'extjs',
#  'web-applications',
#  'hybrid-mobile-app',
#  'keystore',
#  'keytool',
#  'rust',
#  'analysis',
#  'research',
#  'imdb',
#  'api',
#  'curl',
#  'stripe-payments',
#  'uitableview',
#  'cocoa-touch',
#  'matlab',
#  'image-processing',
#  'save',
#  'android-manifest',
#  'canvas',
#  'ipython',
#  'executable',
#  'osx',
#  'iterm2',
#  'fpdf',
#  'owncloud',
#  'search',
#  'time-complexity',
#  'arm',
#  'python-3.x',
#  'typeerror',
#  'file-io',
#  'permissions',
#  'oracle',
#  'datetime',
#  'widget',
#  'shiny',
#  'sidebar',
#  'user-interface',
#  'xna',
#  'xna-4.0',
#  'monogame',
#  'validation',
#  'zend-framework2',
#  'mobile-safari',
#  'frontend',
#  'uiwebview',
#  'chat',
#  'mongoose',
#  'mechanicalturk',
#  'facebook',
#  'apache',
#  'chmod',
#  'chown',
#  'chgrp',
#  'linq',
#  'sortedset',
#  '.net-4.6',
#  'pandas',
#  'average',
#  'netbeans',
#  'javafx',
#  'scenebuilder',
#  'unix',
#  'sh',
#  'glob',
#  'mongoexport',
#  'strongly-typed-dataset',
#  'mdf',
#  'visual-studio-2015',
#  'uiactivityviewcontroller',
#  'bukkit',
#  'formatting',
#  'sublimetext3',
#  'sublimetext',
#  'stylus',
#  'sublime-text-plugin',
#  'paypal',
#  'photokit',
#  'caching',
#  'benchmarking',
#  'percona',
#  'sysbench',
#  'pic',
#  'mplab',
#  'for-loop',
#  'return',
#  'edit',
#  'silverstripe',
#  'printing',
#  'operating-system',
#  'ember.js',
#  'handlebars.js',
#  'winforms',
#  'eloquent',
#  'delete-file',
#  'date',
#  'coffeescript',
#  'timestamp',
#  'memory-management',
#  'jvm',
#  'out-of-memory',
#  'vbscript',
#  'vb6',
#  'ironpython',
#  'spotfire',
#  'ssl',
#  'certificate',
#  'mutual-authentication',
#  'github',
#  'github-pages',
#  'asp.net-mvc',
#  'miniprofiler',
#  'semantic-ui',
#  'video',
#  'vine',
#  'jdbc',
#  'integration-testing',
#  'cdi',
#  'layout',
#  'open-source',
#  'ibatis',
#  'directory',
#  'include',
#  'navbar',
#  'most-vexing-parse',
#  'laravel',
#  'laravel-5',
#  'bitbucket',
#  'webhooks',
#  'phantomjs',
#  'transitions',
#  'dst',
#  'flash',
#  'audio',
#  'visualizer',
#  'angularjs-ui-router',
#  'comparison',
#  'jtable',
#  'tablemodel',
#  'memory-leaks',
#  'leakcanary',
#  'sprite-kit',
#  'skphysicsjoint',
#  'photos',
#  'alasset',
#  'phasset',
#  'serialization',
#  'android-fragments',
#  'sockets',
#  'jira',
#  'object',
#  'control',
#  'computer-vision',
#  'edge-detection',
#  'opencv-contour',
#  'null',
#  'linked-list',
#  'segmentation-fault',
#  'ipad',
#  'ipad-mini',
#  'mocking',
#  'mockito',
#  'powermockito',
#  'mongodb-query',
#  'loops',
#  'slice',
#  'braintree',
#  'swagger-2.0',
#  'vb6-migration',
#  'sql-server-2008-r2',
#  'matrix',
#  'vector',
#  'io',
#  'oop',
#  'design-patterns',
#  'dns',
#  'amazon-route53',
#  'onclicklistener',
#  'ontouchlistener',
#  'google-chrome-extension',
#  'usb',
#  'drive',
#  'emulate',
#  'kendo-ui',
#  'odbc',
#  'if-statement',
#  'setinterval',
#  'rawsql',
#  'ssl-certificate',
#  'openshift',
#  'telegram-bot',
#  'symfony2',
#  'service',
#  'doctrine',
#  'sharepoint',
#  'tfs',
#  'tfs2013',
#  'ng-grid',
#  'debugging',
#  'haskell',
#  'lambda',
#  'twilio',
#  'android-toolbar',
#  'tkinter',
#  'clipboard',
#  'localhost',
#  'local-database',
#  'grep',
#  'scale',
#  'arduino',
#  'gem',
#  'sqlite3-ruby',
#  'html5-video',
#  'bower',
#  'stealjs',
#  'select',
#  'database-design',
#  'opencl',
#  'assembly',
#  'pdo',
#  'rss',
#  'forms',
#  'option',
#  'three.js',
#  'blade',
#  'gis',
#  'jung',
#  'arraylist',
#  'import',
#  'export',
#  'homebrew',
#  'homebrew-cask',
#  'xcode6',
#  'filepath',
#  'enfinity',
#  'selenium',
#  'webdriver-io',
#  'base64',
#  'md5',
#  'openldap',
#  'bcrypt',
#  'uikit',
#  'uidocument',
#  'robots.txt',
#  'gulp',
#  'aggregation-framework',
#  'oauth',
#  'yahoo-api',
#  'split',
#  'records',
#  'websocket',
#  'cross-domain',
#  'homescreen',
#  'hbase',
#  'aspect-ratio',
#  'monodroid',
#  'workflow-foundation-4',
#  'iphone',
#  'excel-interop',
#  'excel-template',
#  'outlook',
#  'dependency-injection',
#  'dagger',
#  'sbt',
#  'rest',
#  'hapijs',
#  'image',
#  'list',
#  'data.frame',
#  'mapply',
#  'inheritance',
#  'superclass',
#  'file',
#  'path',
#  'auto-generate',
#  'google-maps',
#  'geolocation',
#  'latitude-longitude',
#  'drop-down-menu',
#  'plinq',
#  'aggregateexception',
#  'camera',
#  'photolibrary',
#  'phfetchoptions',
#  'stack-trace',
#  'tombstoning',
#  'tombstone',
#  'encryption',
#  'message',
#  'graph',
#  'computer-science',
#  'graph-theory',
#  'theory',
#  'imagemagick',
#  'imagemagick-convert',
#  'querydsl',
#  'automatic-ref-counting',
#  'release',
#  'retain',
#  'screen-orientation',
#  'stdin',
#  'arduino-yun',
#  'temboo',
#  'jmeter',
#  'citrix',
#  'sqlite3',
#  'header-files',
#  'yaml',
#  'union',
#  'emacs',
#  'order',
#  'elisp',
#  'lag',
#  'fps',
#  'xcode7-beta6',
#  'phpexcel',
#  'android-tablayout',
#  'shoes',
#  'cpu-registers',
#  'arm64',
#  'ms-office',
#  'java.util.scanner',
#  'fromfile',
#  'memory',
#  'caemitterlayer',
#  'caemittercell',
#  'twitter-bootstrap-3',
#  'itunesconnect',
#  'swift2',
#  'awk',
#  'libgdx',
#  'angularjs-ng-repeat',
#  'material-design-lite',
#  'textview',
#  'locale',
#  'android-appwidget',
#  'keyboard',
#  'in-app-purchase',
#  'sass',
#  'bootstrap-sass',
#  'pundit',
#  'android-layout',
#  'android-scrollbar',
#  'cookies',
#  'compatibility',
#  'core-location',
#  'amazon-s3',
#  'uiview',
#  'ios-autolayout',
#  'templates',
#  'go',
#  'range',
#  'soap',
#  'xml-namespaces',
#  'filemaker',
#  'dojo',
#  'cakephp',
#  'recaptcha',
#  'redis',
#  'jedis',
#  'skspritenode',
#  'skphysicsbody',
#  'ffmpeg',
#  'video-streaming',
#  'bundler',
#  'wkhtmltopdf',
#  'pdfkit',
#  'uitextfield',
#  'string-split',
#  'xaml',
#  'scrollviewer',
#  'insert',
#  'colors',
#  'histogram',
#  'mean',
#  'mvvmcross',
#  'android-studio',
#  'google-cloud-endpoints',
#  'variadic-templates',
#  'plot',
#  'visual-studio-2013',
#  'webgl',
#  'entity-framework-6',
#  'ruby-on-rails-4',
#  'rails-activerecord',
#  'sql-injection',
#  'sanitization',
#  'config',
#  '.htaccess',
#  'mod-rewrite',
#  'tomcat',
#  'numpy',
#  'runtime-error',
#  'warnings',
#  'infinity',
#  'selenium-webdriver',
#  'window-handles',
#  'contact-form-7']

# %%
# Display sorted dict
for key in sorted(tags_counts, key=tags_counts.get, reverse=True):
    print ("tag #{0} - {1} - {2}".format(key, all_tags[int(key)], tags_counts[key]))
# Out:
# tag #0 - javascript - 59
# tag #36 - php - 50
# tag #30 - java - 41
# tag #22 - android - 33
# tag #13 - ios - 32
# tag #56 - c# - 31
# tag #17 - html - 26
# tag #8 - jquery - 25
# tag #37 - mysql - 22
# tag #18 - css - 22
# tag #70 - c++ - 21
# tag #59 - python - 20
# tag #41 - swift - 17
# tag #61 - sql - 14
# tag #81 - arrays - 14
# tag #16 - node.js - 13
# tag #114 - ruby-on-rails - 12
# tag #79 - angularjs - 11
# tag #27 - c - 11
# tag #75 - r - 11
# tag #14 - objective-c - 9
# tag #126 - wordpress - 8
# tag #195 - database - 8
# tag #54 - linux - 8
# tag #86 - parse.com - 7
# tag #28 - algorithm - 7
# tag #57 - asp.net - 7
# tag #3 - mongodb - 7
# tag #85 - xcode - 7
# tag #109 - html5 - 7
# tag #175 - ruby - 6
# tag #190 - json - 6
# tag #201 - .net - 6
# tag #144 - bash - 6
# tag #231 - wpf - 5
# tag #183 - windows - 5
# tag #246 - table - 5
# tag #295 - android-activity - 5
# tag #117 - function - 5
# tag #78 - excel - 4
# tag #262 - amazon-web-services - 4
# tag #444 - android-fragments - 4
# tag #290 - pointers - 4
# tag #202 - vb.net - 4
# tag #193 - python-2.7 - 4
# tag #422 - laravel - 4
# tag #191 - xml - 4
# tag #495 - debugging - 4
# tag #214 - twitter-bootstrap - 4
# tag #125 - ajax - 4
# tag #225 - sorting - 3
# tag #131 - button - 3
# tag #122 - cordova - 3
# tag #97 - excel-vba - 3
# tag #40 - multithreading - 3
# tag #123 - ionic-framework - 3
# tag #258 - session - 3
# tag #99 - laravel-5.1 - 3
# tag #445 - sockets - 3
# tag #447 - object - 3
# tag #438 - sprite-kit - 3
# tag #1 - google-spreadsheet - 3
# tag #325 - python-3.x - 3
# tag #197 - c++11 - 3
# tag #310 - cocoa-touch - 3
# tag #203 - postgresql - 3
# tag #318 - osx - 3
# tag #51 - maven - 3
# tag #120 - performance - 3
# tag #88 - string - 3
# tag #49 - eclipse - 3
# tag #205 - django - 3
# tag #257 - pdf - 3
# tag #330 - datetime - 3
# tag #95 - sqlite - 2
# tag #162 - mysqli - 2
# tag #33 - server - 2
# tag #248 - css3 - 2
# tag #128 - ios8 - 2
# tag #294 - android-intent - 2
# tag #515 - assembly - 2
# tag #461 - loops - 2
# tag #312 - image-processing - 2
# tag #44 - scala - 2
# tag #399 - vb6 - 2
# tag #518 - forms - 2
# tag #410 - video - 2
# tag #74 - regex - 2
# tag #92 - dictionary - 2
# tag #442 - phasset - 2
# tag #63 - sql-server-2012 - 2
# tag #329 - oracle - 2
# tag #90 - svg - 2
# tag #115 - nested-forms - 2
# tag #324 - arm - 2
# tag #139 - arguments - 2
# tag #455 - ipad - 2
# tag #460 - mongodb-query - 2
# tag #229 - joptionpane - 2
# tag #206 - responsive-design - 2
# tag #164 - visual-c++ - 2
# tag #342 - uiwebview - 2
# tag #334 - user-interface - 2
# tag #91 - exception - 2
# tag #640 - cookies - 2
# tag #314 - android-manifest - 2
# tag #554 - iphone - 2
# tag #118 - while-loop - 2
# tag #418 - directory - 2
# tag #307 - curl - 2
# tag #509 - html5-video - 2
# tag #293 - windows-10 - 2
# tag #267 - google-chrome - 2
# tag #66 - sails.js - 2
# tag #165 - google-app-engine - 2
# tag #289 - devexpress - 2
# tag #575 - drop-down-menu - 2
# tag #220 - woocommerce - 2
# tag #80 - ionic - 2
# tag #532 - selenium - 2
# tag #101 - typescript - 2
# tag #271 - swing - 2
# tag #136 - opencv - 2
# tag #185 - meteor - 2
# tag #160 - logging - 2
# tag #9 - browser - 2
# tag #38 - xslt - 2
# tag #89 - d3.js - 2
# tag #463 - braintree - 2
# tag #224 - sql-server - 2
# tag #344 - mongoose - 2
# tag #468 - vector - 2
# tag #110 - socket.io - 2
# tag #400 - ironpython - 2
# tag #96 - join - 2
# tag #6 - sharepoint-2013 - 2
# tag #163 - c#-4.0 - 2
# tag #430 - audio - 2
# tag #512 - select - 2
# tag #401 - spotfire - 2
# tag #29 - mathematical-optimization - 2
# tag #156 - security - 2
# tag #381 - for-loop - 2
# tag #260 - codeigniter - 2
# tag #135 - qt - 2
# tag #278 - dll - 2
# tag #561 - rest - 2
# tag #669 - colors - 2
# tag #423 - laravel-5 - 2
# tag #454 - segmentation-fault - 2
# tag #545 - split - 2
# tag #429 - flash - 2
# tag #42 - struct - 2
# tag #285 - entity-framework - 2
# tag #520 - three.js - 2
# tag #354 - pandas - 2
# tag #311 - matlab - 2
# tag #552 - monodroid - 2
# tag #301 - keytool - 2
# tag #108 - onclick - 2
# tag #62 - visual-studio - 2
# tag #346 - facebook - 2
# tag #222 - express - 2
# tag #55 - shell - 2
# tag #142 - kendo-grid - 2
# tag #76 - conferencing - 1
# tag #469 - io - 1
# tag #24 - mobilefirst - 1
# tag #221 - variation - 1
# tag #639 - android-scrollbar - 1
# tag #166 - google-api - 1
# tag #642 - core-location - 1
# tag #498 - twilio - 1
# tag #304 - research - 1
# tag #503 - local-database - 1
# tag #50 - spring - 1
# tag #134 - transactions - 1
# tag #233 - bitmap - 1
# tag #533 - webdriver-io - 1
# tag #370 - sublimetext - 1
# tag #238 - structure - 1
# tag #365 - visual-studio-2015 - 1
# tag #349 - chown - 1
# tag #254 - wordpress-plugin - 1
# tag #632 - android-appwidget - 1
# tag #4 - nosql - 1
# tag #288 - xlrd - 1
# tag #68 - dispatch - 1
# tag #663 - pdfkit - 1
# tag #31 - swap - 1
# tag #550 - hbase - 1
# tag #527 - homebrew - 1
# tag #578 - camera - 1
# tag #60 - macros - 1
# tag #594 - release - 1
# tag #627 - libgdx - 1
# tag #659 - ffmpeg - 1
# tag #407 - asp.net-mvc - 1
# tag #339 - zend-framework2 - 1
# tag #584 - encryption - 1
# tag #544 - yahoo-api - 1
# tag #395 - memory-management - 1
# tag #597 - stdin - 1
# tag #390 - eloquent - 1
# tag #504 - grep - 1
# tag #64 - delphi - 1
# tag #537 - bcrypt - 1
# tag #327 - file-io - 1
# tag #492 - tfs - 1
# tag #662 - wkhtmltopdf - 1
# tag #272 - wget - 1
# tag #296 - recyclerview - 1
# tag #405 - github - 1
# tag #402 - ssl - 1
# tag #306 - api - 1
# tag #619 - fromfile - 1
# tag #209 - unity3d - 1
# tag #45 - routes - 1
# tag #328 - permissions - 1
# tag #522 - gis - 1
# tag #177 - twitter - 1
# tag #171 - relation - 1
# tag #417 - ibatis - 1
# tag #478 - drive - 1
# tag #199 - auto - 1
# tag #277 - sync - 1
# tag #112 - depth - 1
# tag #236 - image-load - 1
# tag #268 - diffie-hellman - 1
# tag #543 - oauth - 1
# tag #111 - kinect - 1
# tag #494 - ng-grid - 1
# tag #167 - google-api-client - 1
# tag #47 - spray - 1
# tag #373 - paypal - 1
# tag #574 - latitude-longitude - 1
# tag #332 - shiny - 1
# tag #291 - dynamic - 1
# tag #485 - ssl-certificate - 1
# tag #563 - image - 1
# tag #297 - extjs - 1
# tag #674 - google-cloud-endpoints - 1
# tag #71 - visual-studio-2010 - 1
# tag #564 - list - 1
# tag #333 - sidebar - 1
# tag #490 - doctrine - 1
# tag #43 - mutators - 1
# tag #143 - scheme - 1
# tag #630 - textview - 1
# tag #298 - web-applications - 1
# tag #434 - jtable - 1
# tag #571 - auto-generate - 1
# tag #577 - aggregateexception - 1
# tag #239 - banking - 1
# tag #530 - filepath - 1
# tag #355 - average - 1
# tag #181 - generator - 1
# tag #32 - jestjs - 1
# tag #568 - superclass - 1
# tag #10 - passwords - 1
# tag #679 - entity-framework-6 - 1
# tag #476 - google-chrome-extension - 1
# tag #234 - universal-image-loader - 1
# tag #283 - iis - 1
# tag #436 - memory-leaks - 1
# tag #483 - setinterval - 1
# tag #406 - github-pages - 1
# tag #612 - phpexcel - 1
# tag #435 - tablemodel - 1
# tag #637 - pundit - 1
# tag #394 - timestamp - 1
# tag #613 - android-tablayout - 1
# tag #655 - redis - 1
# tag #275 - filter - 1
# tag #11 - .post - 1
# tag #5 - couchdb - 1
# tag #276 - bind - 1
# tag #105 - ibeacon - 1
# tag #603 - header-files - 1
# tag #302 - rust - 1
# tag #93 - casting - 1
# tag #521 - blade - 1
# tag #560 - sbt - 1
# tag #626 - awk - 1
# tag #273 - speech-recognition - 1
# tag #672 - mvvmcross - 1
# tag #106 - android-ibeacon - 1
# tag #261 - cart - 1
# tag #677 - visual-studio-2013 - 1
# tag #647 - go - 1
# tag #386 - operating-system - 1
# tag #315 - canvas - 1
# tag #668 - insert - 1
# tag #119 - compiler-errors - 1
# tag #245 - onchange - 1
# tag #450 - edge-detection - 1
# tag #610 - fps - 1
# tag #525 - import - 1
# tag #437 - leakcanary - 1
# tag #172 - pfobject - 1
# tag #279 - static - 1
# tag #208 - random - 1
# tag #228 - fullscreen - 1
# tag #487 - telegram-bot - 1
# tag #368 - formatting - 1
# tag #665 - string-split - 1
# tag #590 - imagemagick - 1
# tag #440 - photos - 1
# tag #484 - rawsql - 1
# tag #357 - javafx - 1
# tag #601 - citrix - 1
# tag #682 - sql-injection - 1
# tag #26 - mobilefirst-adapters - 1
# tag #411 - vine - 1
# tag #538 - uikit - 1
# tag #608 - elisp - 1
# tag #666 - xaml - 1
# tag #21 - marketo - 1
# tag #471 - design-patterns - 1
# tag #173 - private-key - 1
# tag #566 - mapply - 1
# tag #217 - grouping - 1
# tag #362 - mongoexport - 1
# tag #378 - sysbench - 1
# tag #480 - kendo-ui - 1
# tag #692 - selenium-webdriver - 1
# tag #488 - symfony2 - 1
# tag #189 - varnish-vcl - 1
# tag #426 - phantomjs - 1
# tag #414 - cdi - 1
# tag #249 - signal-processing - 1
# tag #326 - typeerror - 1
# tag #651 - filemaker - 1
# tag #580 - phfetchoptions - 1
# tag #393 - coffeescript - 1
# tag #322 - search - 1
# tag #473 - amazon-route53 - 1
# tag #431 - visualizer - 1
# tag #200 - type-deduction - 1
# tag #433 - comparison - 1
# tag #380 - mplab - 1
# tag #213 - xrange - 1
# tag #319 - iterm2 - 1
# tag #581 - stack-trace - 1
# tag #263 - xts - 1
# tag #216 - dataset - 1
# tag #645 - ios-autolayout - 1
# tag #472 - dns - 1
# tag #536 - openldap - 1
# tag #466 - sql-server-2008-r2 - 1
# tag #528 - homebrew-cask - 1
# tag #227 - jframe - 1
# tag #194 - unity - 1
# tag #347 - apache - 1
# tag #685 - .htaccess - 1
# tag #499 - android-toolbar - 1
# tag #287 - asp.net-web-api2 - 1
# tag #331 - widget - 1
# tag #157 - virtual-machine - 1
# tag #127 - ios7 - 1
# tag #534 - base64 - 1
# tag #559 - dagger - 1
# tag #565 - data.frame - 1
# tag #635 - sass - 1
# tag #15 - uipopovercontroller - 1
# tag #451 - opencv-contour - 1
# tag #323 - time-complexity - 1
# tag #303 - analysis - 1
# tag #583 - tombstone - 1
# tag #345 - mechanicalturk - 1
# tag #585 - message - 1
# tag #169 - android-wear - 1
# tag #284 - owin - 1
# tag #646 - templates - 1
# tag #343 - chat - 1
# tag #250 - android-mediaplayer - 1
# tag #351 - linq - 1
# tag #375 - caching - 1
# tag #159 - rss-reader - 1
# tag #680 - ruby-on-rails-4 - 1
# tag #53 - spring-boot - 1
# tag #372 - sublime-text-plugin - 1
# tag #219 - attributes - 1
# tag #309 - uitableview - 1
# tag #548 - cross-domain - 1
# tag #259 - durandal-2.0 - 1
# tag #555 - excel-interop - 1
# tag #137 - web-crawler - 1
# tag #7 - document-management - 1
# tag #286 - asp.net-web-api - 1
# tag #511 - stealjs - 1
# tag #582 - tombstoning - 1
# tag #416 - open-source - 1
# tag #452 - null - 1
# tag #243 - testcomplete - 1
# tag #292 - indirection - 1
# tag #408 - miniprofiler - 1
# tag #48 - akka-http - 1
# tag #475 - ontouchlistener - 1
# tag #353 - .net-4.6 - 1
# tag #425 - webhooks - 1
# tag #629 - material-design-lite - 1
# tag #12 - sql-server-2008 - 1
# tag #313 - save - 1
# tag #168 - google-api-python-client - 1
# tag #384 - silverstripe - 1
# tag #65 - notifications - 1
# tag #132 - download - 1
# tag #409 - semantic-ui - 1
# tag #623 - twitter-bootstrap-3 - 1
# tag #465 - vb6-migration - 1
# tag #641 - compatibility - 1
# tag #242 - pop - 1
# tag #572 - google-maps - 1
# tag #441 - alasset - 1
# tag #424 - bitbucket - 1
# tag #77 - simplecart - 1
# tag #516 - pdo - 1
# tag #602 - sqlite3 - 1
# tag #244 - v8 - 1
# tag #226 - hybrid - 1
# tag #361 - glob - 1
# tag #477 - usb - 1
# tag #489 - service - 1
# tag #501 - clipboard - 1
# tag #634 - in-app-purchase - 1
# tag #514 - opencl - 1
# tag #98 - laravel-routing - 1
# tag #448 - control - 1
# tag #148 - smalltalk - 1
# tag #174 - cryptographicexception - 1
# tag #363 - strongly-typed-dataset - 1
# tag #428 - dst - 1
# tag #551 - aspect-ratio - 1
# tag #145 - terminal - 1
# tag #684 - config - 1
# tag #500 - tkinter - 1
# tag #186 - console - 1
# tag #491 - sharepoint - 1
# tag #546 - records - 1
# tag #392 - date - 1
# tag #178 - cloudera - 1
# tag #569 - file - 1
# tag #573 - geolocation - 1
# tag #459 - powermockito - 1
# tag #383 - edit - 1
# tag #235 - memorycache - 1
# tag #664 - uitextfield - 1
# tag #415 - layout - 1
# tag #382 - return - 1
# tag #690 - warnings - 1
# tag #604 - yaml - 1
# tag #308 - stripe-payments - 1
# tag #523 - jung - 1
# tag #102 - react-jsx - 1
# tag #140 - raw-types - 1
# tag #439 - skphysicsjoint - 1
# tag #621 - caemitterlayer - 1
# tag #549 - homescreen - 1
# tag #598 - arduino-yun - 1
# tag #94 - hashmap - 1
# tag #510 - bower - 1
# tag #387 - ember.js - 1
# tag #150 - heroku - 1
# tag #265 - file-get-contents - 1
# tag #338 - validation - 1
# tag #636 - bootstrap-sass - 1
# tag #103 - socrata - 1
# tag #456 - ipad-mini - 1
# tag #539 - uidocument - 1
# tag #529 - xcode6 - 1
# tag #104 - soda - 1
# tag #141 - telerik - 1
# tag #154 - crash - 1
# tag #624 - itunesconnect - 1
# tag #282 - django-rest-framework - 1
# tag #389 - winforms - 1
# tag #586 - graph - 1
# tag #366 - uiactivityviewcontroller - 1
# tag #358 - scenebuilder - 1
# tag #364 - mdf - 1
# tag #39 - orders - 1
# tag #589 - theory - 1
# tag #385 - printing - 1
# tag #481 - odbc - 1
# tag #367 - bukkit - 1
# tag #650 - xml-namespaces - 1
# tag #83 - time - 1
# tag #505 - scale - 1
# tag #23 - worklight - 1
# tag #638 - android-layout - 1
# tag #643 - amazon-s3 - 1
# tag #281 - view - 1
# tag #264 - rbind - 1
# tag #497 - lambda - 1
# tag #352 - sortedset - 1
# tag #681 - rails-activerecord - 1
# tag #147 - combobox - 1
# tag #562 - hapijs - 1
# tag #188 - varnish - 1
# tag #299 - hybrid-mobile-app - 1
# tag #591 - imagemagick-convert - 1
# tag #558 - dependency-injection - 1
# tag #305 - imdb - 1
# tag #266 - unset - 1
# tag #457 - mocking - 1
# tag #617 - ms-office - 1
# tag #420 - navbar - 1
# tag #58 - iframe - 1
# tag #616 - arm64 - 1
# tag #176 - hadoop - 1
# tag #356 - netbeans - 1
# tag #625 - swift2 - 1
# tag #274 - cmusphinx - 1
# tag #320 - fpdf - 1
# tag #599 - temboo - 1
# tag #593 - automatic-ref-counting - 1
# tag #649 - soap - 1
# tag #149 - pharo - 1
# tag #403 - certificate - 1
# tag #211 - unityscript - 1
# tag #453 - linked-list - 1
# tag #255 - wordpress-theming - 1
# tag #683 - sanitization - 1
# tag #280 - noclassdeffounderror - 1
# tag #192 - diameter-protocol - 1
# tag #240 - julia-lang - 1
# tag #2 - scrape - 1
# tag #678 - webgl - 1
# tag #620 - memory - 1
# tag #34 - centos6 - 1
# tag #350 - chgrp - 1
# tag #508 - sqlite3-ruby - 1
# tag #253 - pseudocode - 1
# tag #667 - scrollviewer - 1
# tag #20 - gmail - 1
# tag #675 - variadic-templates - 1
# tag #661 - bundler - 1
# tag #421 - most-vexing-parse - 1
# tag #269 - internet-explorer-10 - 1
# tag #348 - chmod - 1
# tag #374 - photokit - 1
# tag #567 - inheritance - 1
# tag #35 - yum - 1
# tag #587 - computer-science - 1
# tag #486 - openshift - 1
# tag #660 - video-streaming - 1
# tag #633 - keyboard - 1
# tag #138 - enums - 1
# tag #614 - shoes - 1
# tag #531 - enfinity - 1
# tag #694 - contact-form-7 - 1
# tag #133 - hibernate - 1
# tag #506 - arduino - 1
# tag #404 - mutual-authentication - 1
# tag #379 - pic - 1
# tag #474 - onclicklistener - 1
# tag #210 - scripting - 1
# tag #606 - emacs - 1
# tag #158 - vmware - 1
# tag #87 - uiimage - 1
# tag #359 - unix - 1
# tag #689 - runtime-error - 1
# tag #179 - flume - 1
# tag #300 - keystore - 1
# tag #688 - numpy - 1
# tag #398 - vbscript - 1
# tag #316 - ipython - 1
# tag #611 - xcode7-beta6 - 1
# tag #25 - worklight-adapters - 1
# tag #170 - android-wear-notification - 1
# tag #542 - aggregation-framework - 1
# tag #432 - angularjs-ui-router - 1
# tag #129 - cllocationmanager - 1
# tag #337 - monogame - 1
# tag #657 - skspritenode - 1
# tag #553 - workflow-foundation-4 - 1
# tag #458 - mockito - 1
# tag #671 - mean - 1
# tag #592 - querydsl - 1
# tag #517 - rss - 1
# tag #155 - garbage-collection - 1
# tag #596 - screen-orientation - 1
# tag #182 - ecmascript-6 - 1
# tag #496 - haskell - 1
# tag #579 - photolibrary - 1
# tag #46 - akka - 1
# tag #218 - aggregate - 1
# tag #686 - mod-rewrite - 1
# tag #84 - format - 1
# tag #152 - worker - 1
# tag #151 - playback - 1
# tag #247 - wolfram-mathematica - 1
# tag #270 - object-oriented-analysis - 1
# tag #184 - powershell - 1
# tag #413 - integration-testing - 1
# tag #388 - handlebars.js - 1
# tag #237 - data - 1
# tag #519 - option - 1
# tag #212 - spawn - 1
# tag #130 - testflight - 1
# tag #658 - skphysicsbody - 1
# tag #369 - sublimetext3 - 1
# tag #412 - jdbc - 1
# tag #687 - tomcat - 1
# tag #336 - xna-4.0 - 1
# tag #52 - jboss - 1
# tag #153 - procfile - 1
# tag #377 - percona - 1
# tag #673 - android-studio - 1
# tag #600 - jmeter - 1
# tag #19 - email - 1
# tag #69 - vagrant - 1
# tag #462 - slice - 1
# tag #397 - out-of-memory - 1
# tag #446 - jira - 1
# tag #628 - angularjs-ng-repeat - 1
# tag #391 - delete-file - 1
# tag #73 - fstream - 1
# tag #588 - graph-theory - 1
# tag #180 - asynchronous - 1
# tag #557 - outlook - 1
# tag #654 - recaptcha - 1
# tag #198 - gcc - 1
# tag #502 - localhost - 1
# tag #427 - transitions - 1
# tag #256 - wordpress-mu - 1
# tag #196 - automation - 1
# tag #507 - gem - 1
# tag #252 - audiotrack - 1
# tag #116 - clojure - 1
# tag #443 - serialization - 1
# tag #676 - plot - 1
# tag #371 - stylus - 1
# tag #230 - jcifs - 1
# tag #449 - computer-vision - 1
# tag #317 - executable - 1
# tag #232 - listbox - 1
# tag #215 - modal-dialog - 1
# tag #607 - order - 1
# tag #479 - emulate - 1
# tag #609 - lag - 1
# tag #656 - jedis - 1
# tag #653 - cakephp - 1
# tag #396 - jvm - 1
# tag #360 - sh - 1
# tag #644 - uiview - 1
# tag #576 - plinq - 1
# tag #187 - console-application - 1
# tag #541 - gulp - 1
# tag #121 - selector - 1
# tag #341 - frontend - 1
# tag #241 - uinavigationcontroller - 1
# tag #251 - audio-recording - 1
# tag #470 - oop - 1
# tag #652 - dojo - 1
# tag #693 - window-handles - 1
# tag #376 - benchmarking - 1
# tag #547 - websocket - 1
# tag #524 - arraylist - 1
# tag #464 - swagger-2.0 - 1
# tag #622 - caemittercell - 1
# tag #631 - locale - 1
# tag #419 - include - 1
# tag #513 - database-design - 1
# tag #467 - matrix - 1
# tag #100 - reactjs - 1
# tag #570 - path - 1
# tag #540 - robots.txt - 1
# tag #670 - histogram - 1
# tag #535 - md5 - 1
# tag #207 - html5-canvas - 1
# tag #556 - excel-template - 1
# tag #113 - point-clouds - 1
# tag #595 - retain - 1
# tag #691 - infinity - 1
# tag #493 - tfs2013 - 1
# tag #526 - export - 1
# tag #618 - java.util.scanner - 1
# tag #335 - xna - 1
# tag #223 - loopbackjs - 1
# tag #648 - range - 1
# tag #72 - text - 1
# tag #482 - if-statement - 1
# tag #67 - nsthread - 1
# tag #605 - union - 1
# tag #321 - owncloud - 1
# tag #340 - mobile-safari - 1
# tag #146 - csv - 1
# tag #161 - log4j - 1
# tag #204 - pgrouting - 1
# tag #615 - cpu-registers - 1
# tag #82 - cost-based-optimizer - 1
# tag #124 - objective - 1
# tag #107 - internet-explorer - 1

# %%
len(all_tags)
# Out:
# 695

# %%
cooccur_dict
# Out:
# {'0': {'1': 3,
#   '100': 1,
#   '101': 1,
#   '102': 1,
#   '109': 3,
#   '110': 1,
#   '114': 1,
#   '117': 1,
#   '120': 1,
#   '121': 1,
#   '125': 2,
#   '13': 1,
#   '16': 6,
#   '17': 12,
#   '18': 6,
#   '180': 1,
#   '181': 1,
#   '182': 1,
#   '190': 1,
#   '2': 1,
#   '214': 1,
#   '225': 2,
#   '226': 1,
#   '243': 1,
#   '244': 1,
#   '245': 1,
#   '246': 1,
#   '248': 2,
#   '262': 1,
#   '27': 1,
#   '297': 1,
#   '3': 1,
#   '30': 1,
#   '315': 1,
#   '32': 1,
#   '338': 1,
#   '344': 1,
#   '346': 1,
#   '36': 5,
#   '381': 1,
#   '382': 1,
#   '387': 1,
#   '388': 1,
#   '392': 1,
#   '393': 1,
#   '394': 1,
#   '410': 1,
#   '411': 1,
#   '433': 1,
#   '445': 1,
#   '447': 1,
#   '460': 1,
#   '461': 1,
#   '482': 1,
#   '483': 1,
#   '505': 1,
#   '516': 1,
#   '517': 1,
#   '520': 2,
#   '547': 1,
#   '548': 1,
#   '56': 2,
#   '561': 1,
#   '563': 1,
#   '57': 2,
#   '59': 1,
#   '620': 1,
#   '643': 1,
#   '652': 1,
#   '678': 1,
#   '70': 1,
#   '76': 1,
#   '78': 1,
#   '79': 2,
#   '8': 17,
#   '81': 4,
#   '88': 1,
#   '89': 1,
#   '90': 1},
#  '1': {'0': 3, '17': 1, '2': 1, '78': 1},
#  '10': {'11': 1, '8': 1, '9': 1},
#  '100': {'0': 1, '101': 1, '102': 1},
#  '101': {'0': 1, '100': 1, '102': 1, '62': 1},
#  '102': {'0': 1, '100': 1, '101': 1},
#  '103': {'104': 1, '56': 1},
#  '104': {'103': 1, '56': 1},
#  '105': {'106': 1, '22': 1, '30': 1},
#  '106': {'105': 1, '22': 1, '30': 1},
#  '107': {'108': 1, '8': 1},
#  '108': {'107': 1, '22': 1, '444': 1, '474': 1, '475': 1, '8': 1},
#  '109': {'0': 3,
#   '110': 1,
#   '16': 1,
#   '18': 1,
#   '214': 1,
#   '22': 1,
#   '248': 1,
#   '298': 1,
#   '299': 1,
#   '410': 1,
#   '509': 2,
#   '659': 1,
#   '660': 1,
#   '8': 1},
#  '11': {'10': 1, '8': 1, '9': 1},
#  '110': {'0': 1, '109': 1, '16': 1, '22': 1, '295': 1, '445': 1},
#  '111': {'112': 1, '113': 1},
#  '112': {'111': 1, '113': 1},
#  '113': {'111': 1, '112': 1},
#  '114': {'0': 1,
#   '115': 2,
#   '175': 2,
#   '18': 1,
#   '195': 1,
#   '196': 1,
#   '214': 2,
#   '215': 1,
#   '258': 1,
#   '262': 1,
#   '318': 1,
#   '498': 1,
#   '507': 1,
#   '508': 1,
#   '635': 1,
#   '636': 1,
#   '637': 1,
#   '640': 1,
#   '643': 1,
#   '661': 1,
#   '662': 1,
#   '663': 1},
#  '115': {'114': 2},
#  '116': {},
#  '117': {'0': 1,
#   '118': 1,
#   '119': 1,
#   '13': 1,
#   '290': 1,
#   '381': 1,
#   '382': 1,
#   '41': 1,
#   '545': 1,
#   '546': 1,
#   '70': 1,
#   '75': 1,
#   '79': 1,
#   '80': 1},
#  '118': {'117': 1, '119': 1, '381': 1, '584': 1, '585': 1, '59': 1, '75': 1},
#  '119': {'117': 1, '118': 1, '75': 1},
#  '12': {},
#  '120': {'0': 1,
#   '121': 1,
#   '324': 1,
#   '515': 1,
#   '609': 1,
#   '610': 1,
#   '611': 1,
#   '615': 1,
#   '616': 1},
#  '121': {'0': 1, '120': 1},
#  '122': {'123': 2, '22': 1, '684': 1},
#  '123': {'122': 2, '79': 1},
#  '124': {'13': 1},
#  '125': {'0': 2, '126': 1, '246': 1, '36': 3, '37': 1, '8': 2},
#  '126': {'125': 1,
#   '219': 1,
#   '220': 2,
#   '221': 1,
#   '254': 1,
#   '255': 1,
#   '256': 1,
#   '36': 5,
#   '463': 2,
#   '694': 1,
#   '8': 1},
#  '127': {'128': 1, '129': 1, '13': 1, '130': 1},
#  '128': {'127': 1, '129': 1, '13': 2, '130': 1, '455': 1, '456': 1},
#  '129': {'127': 1, '128': 1, '13': 1, '130': 1},
#  '13': {'0': 1,
#   '117': 1,
#   '124': 1,
#   '127': 1,
#   '128': 2,
#   '129': 1,
#   '130': 1,
#   '14': 6,
#   '15': 1,
#   '159': 1,
#   '241': 1,
#   '242': 1,
#   '257': 1,
#   '309': 1,
#   '310': 3,
#   '342': 2,
#   '346': 1,
#   '366': 1,
#   '374': 1,
#   '41': 8,
#   '410': 1,
#   '411': 1,
#   '416': 1,
#   '438': 1,
#   '439': 1,
#   '440': 1,
#   '441': 1,
#   '442': 2,
#   '455': 2,
#   '456': 1,
#   '495': 1,
#   '538': 1,
#   '539': 1,
#   '554': 2,
#   '578': 1,
#   '579': 1,
#   '580': 1,
#   '621': 1,
#   '622': 1,
#   '624': 1,
#   '625': 1,
#   '641': 1,
#   '642': 1,
#   '644': 1,
#   '645': 1,
#   '664': 1,
#   '67': 1,
#   '68': 1,
#   '81': 1,
#   '85': 5,
#   '86': 4,
#   '87': 1,
#   '91': 1},
#  '130': {'127': 1, '128': 1, '129': 1, '13': 1},
#  '131': {'132': 1,
#   '17': 1,
#   '18': 1,
#   '183': 1,
#   '231': 1,
#   '36': 1,
#   '56': 1,
#   '677': 1},
#  '132': {'131': 1, '17': 1, '36': 1},
#  '133': {'134': 1},
#  '134': {'133': 1},
#  '135': {'136': 1, '70': 2},
#  '136': {'135': 1, '312': 1, '449': 1, '450': 1, '451': 1, '70': 1},
#  '137': {'22': 1},
#  '138': {'139': 1, '140': 1, '41': 1},
#  '139': {'138': 1, '140': 1, '41': 1, '488': 1, '489': 1, '490': 1},
#  '14': {'13': 6,
#   '15': 1,
#   '241': 1,
#   '242': 1,
#   '310': 1,
#   '374': 1,
#   '41': 1,
#   '593': 1,
#   '594': 1,
#   '595': 1,
#   '644': 1,
#   '645': 1,
#   '67': 1,
#   '68': 1},
#  '140': {'138': 1, '139': 1, '41': 1},
#  '141': {'142': 1},
#  '142': {'141': 1, '480': 1},
#  '143': {},
#  '144': {'145': 1,
#   '156': 1,
#   '157': 1,
#   '158': 1,
#   '190': 1,
#   '272': 1,
#   '54': 1,
#   '55': 1,
#   '626': 1},
#  '145': {'144': 1},
#  '146': {'147': 1, '56': 1},
#  '147': {'146': 1, '56': 1},
#  '148': {'149': 1},
#  '149': {'148': 1},
#  '15': {'13': 1, '14': 1},
#  '150': {'151': 1, '152': 1, '153': 1},
#  '151': {'150': 1, '152': 1, '153': 1},
#  '152': {'150': 1, '151': 1, '153': 1},
#  '153': {'150': 1, '151': 1, '152': 1},
#  '154': {'155': 1, '22': 1, '30': 1},
#  '155': {'154': 1, '22': 1, '30': 1},
#  '156': {'144': 1,
#   '157': 1,
#   '158': 1,
#   '54': 1,
#   '680': 1,
#   '681': 1,
#   '682': 1,
#   '683': 1},
#  '157': {'144': 1, '156': 1, '158': 1, '54': 1},
#  '158': {'144': 1, '156': 1, '157': 1, '54': 1},
#  '159': {'13': 1},
#  '16': {'0': 6,
#   '109': 1,
#   '110': 1,
#   '180': 1,
#   '181': 1,
#   '182': 1,
#   '190': 1,
#   '222': 2,
#   '223': 1,
#   '244': 1,
#   '27': 1,
#   '3': 3,
#   '344': 2,
#   '37': 1,
#   '460': 1,
#   '484': 1,
#   '532': 1,
#   '533': 1,
#   '61': 1,
#   '66': 1,
#   '70': 1},
#  '160': {'161': 1, '30': 2, '51': 1},
#  '161': {'160': 1, '30': 1, '51': 1},
#  '162': {'195': 1, '276': 1, '36': 2},
#  '163': {'164': 1, '186': 1, '187': 1, '27': 1, '56': 2, '70': 1},
#  '164': {'163': 1,
#   '197': 1,
#   '198': 1,
#   '199': 1,
#   '200': 1,
#   '27': 1,
#   '56': 1,
#   '70': 1},
#  '165': {'166': 1, '167': 1, '168': 1, '22': 1, '673': 1, '674': 1},
#  '166': {'165': 1, '167': 1, '168': 1},
#  '167': {'165': 1, '166': 1, '168': 1},
#  '168': {'165': 1, '166': 1, '167': 1},
#  '169': {'170': 1},
#  '17': {'0': 12,
#   '1': 1,
#   '131': 1,
#   '132': 1,
#   '18': 13,
#   '19': 1,
#   '20': 1,
#   '206': 1,
#   '21': 1,
#   '246': 2,
#   '315': 1,
#   '340': 1,
#   '341': 1,
#   '354': 1,
#   '36': 5,
#   '385': 1,
#   '386': 1,
#   '418': 1,
#   '419': 1,
#   '420': 1,
#   '505': 1,
#   '551': 1,
#   '557': 1,
#   '57': 1,
#   '59': 1,
#   '685': 1,
#   '686': 1,
#   '79': 1,
#   '8': 9,
#   '81': 1},
#  '170': {'169': 1},
#  '171': {'172': 1, '41': 1, '86': 1},
#  '172': {'171': 1, '41': 1, '86': 1},
#  '173': {'174': 1},
#  '174': {'173': 1},
#  '175': {'114': 2,
#   '195': 1,
#   '196': 1,
#   '447': 1,
#   '543': 1,
#   '544': 1,
#   '614': 1,
#   '661': 1,
#   '662': 1,
#   '663': 1,
#   '81': 1},
#  '176': {'177': 1, '178': 1, '179': 1},
#  '177': {'176': 1, '178': 1, '179': 1},
#  '178': {'176': 1, '177': 1, '179': 1},
#  '179': {'176': 1, '177': 1, '178': 1},
#  '18': {'0': 6,
#   '109': 1,
#   '114': 1,
#   '131': 1,
#   '17': 13,
#   '19': 1,
#   '20': 1,
#   '206': 2,
#   '207': 1,
#   '21': 1,
#   '214': 2,
#   '248': 1,
#   '269': 1,
#   '340': 1,
#   '341': 1,
#   '346': 1,
#   '385': 1,
#   '386': 1,
#   '409': 1,
#   '505': 1,
#   '551': 1,
#   '557': 1,
#   '57': 1,
#   '623': 1,
#   '635': 1,
#   '636': 1,
#   '8': 7},
#  '180': {'0': 1, '16': 1, '181': 1, '182': 1},
#  '181': {'0': 1, '16': 1, '180': 1, '182': 1},
#  '182': {'0': 1, '16': 1, '180': 1, '181': 1},
#  '183': {'131': 1,
#   '184': 1,
#   '185': 1,
#   '231': 1,
#   '27': 1,
#   '317': 1,
#   '429': 1,
#   '477': 1,
#   '478': 1,
#   '479': 1,
#   '54': 1,
#   '56': 1,
#   '633': 1,
#   '677': 1},
#  '184': {'183': 1, '185': 1},
#  '185': {'183': 1, '184': 1},
#  '186': {'163': 1, '187': 1, '56': 1},
#  '187': {'163': 1, '186': 1, '56': 1},
#  '188': {'189': 1},
#  '189': {'188': 1},
#  '19': {'17': 1, '18': 1, '20': 1, '21': 1},
#  '190': {'0': 1,
#   '144': 1,
#   '16': 1,
#   '191': 1,
#   '192': 1,
#   '36': 1,
#   '37': 1,
#   '464': 1,
#   '89': 1},
#  '191': {'190': 1,
#   '192': 1,
#   '36': 1,
#   '38': 1,
#   '56': 1,
#   '649': 1,
#   '650': 1,
#   '651': 1},
#  '192': {'190': 1, '191': 1},
#  '193': {'205': 1, '281': 1, '282': 1, '288': 1, '325': 1, '59': 3},
#  '194': {},
#  '195': {'114': 1,
#   '162': 1,
#   '175': 1,
#   '196': 1,
#   '203': 1,
#   '276': 1,
#   '329': 1,
#   '36': 2,
#   '37': 2,
#   '513': 1,
#   '518': 1,
#   '602': 1,
#   '61': 2,
#   '668': 1,
#   '95': 1},
#  '196': {'114': 1, '175': 1, '195': 1},
#  '197': {'164': 1, '198': 1, '199': 1, '200': 1, '421': 1, '675': 1, '70': 2},
#  '198': {'164': 1, '197': 1, '199': 1, '200': 1},
#  '199': {'164': 1, '197': 1, '198': 1, '200': 1},
#  '2': {'0': 1, '1': 1},
#  '20': {'17': 1, '18': 1, '19': 1, '21': 1},
#  '200': {'164': 1, '197': 1, '198': 1, '199': 1},
#  '201': {'202': 1,
#   '285': 1,
#   '443': 1,
#   '553': 1,
#   '56': 4,
#   '576': 1,
#   '577': 1,
#   '601': 1},
#  '202': {'201': 1, '365': 1, '398': 1, '399': 1, '97': 1},
#  '203': {'195': 1, '204': 1, '30': 1, '417': 1},
#  '204': {'203': 1},
#  '205': {'193': 1, '281': 1, '282': 1, '572': 1, '573': 1, '574': 1, '59': 3},
#  '206': {'17': 1, '18': 2, '207': 1, '557': 1},
#  '207': {'18': 1, '206': 1},
#  '208': {'209': 1, '210': 1, '211': 1, '212': 1},
#  '209': {'208': 1, '210': 1, '211': 1, '212': 1},
#  '21': {'17': 1, '18': 1, '19': 1, '20': 1},
#  '210': {'208': 1, '209': 1, '211': 1, '212': 1},
#  '211': {'208': 1, '209': 1, '210': 1, '212': 1},
#  '212': {'208': 1, '209': 1, '210': 1, '211': 1},
#  '213': {'59': 1},
#  '214': {'0': 1,
#   '109': 1,
#   '114': 2,
#   '18': 2,
#   '215': 1,
#   '248': 1,
#   '623': 1,
#   '635': 1,
#   '636': 1,
#   '8': 1},
#  '215': {'114': 1, '214': 1},
#  '216': {'217': 1, '218': 1, '28': 1, '30': 1},
#  '217': {'216': 1, '218': 1, '28': 1, '30': 1},
#  '218': {'216': 1, '217': 1, '28': 1, '30': 1},
#  '219': {'126': 1, '220': 1, '221': 1, '36': 1},
#  '22': {'105': 1,
#   '106': 1,
#   '108': 1,
#   '109': 1,
#   '110': 1,
#   '122': 1,
#   '137': 1,
#   '154': 1,
#   '155': 1,
#   '165': 1,
#   '23': 1,
#   '230': 1,
#   '233': 1,
#   '234': 1,
#   '235': 1,
#   '236': 1,
#   '24': 1,
#   '249': 1,
#   '25': 1,
#   '250': 1,
#   '251': 1,
#   '252': 1,
#   '26': 1,
#   '277': 1,
#   '294': 2,
#   '295': 5,
#   '296': 1,
#   '298': 1,
#   '299': 1,
#   '30': 4,
#   '314': 2,
#   '327': 1,
#   '328': 1,
#   '343': 1,
#   '40': 1,
#   '444': 4,
#   '445': 2,
#   '474': 1,
#   '475': 1,
#   '499': 1,
#   '532': 1,
#   '549': 1,
#   '581': 1,
#   '582': 1,
#   '583': 1,
#   '596': 1,
#   '627': 1,
#   '630': 1,
#   '631': 1,
#   '632': 1,
#   '638': 1,
#   '639': 1,
#   '673': 1,
#   '674': 1,
#   '684': 1},
#  '220': {'126': 2, '219': 1, '221': 1, '36': 2},
#  '221': {'126': 1, '219': 1, '220': 1, '36': 1},
#  '222': {'16': 2, '223': 1, '3': 1},
#  '223': {'16': 1, '222': 1},
#  '224': {'502': 1, '503': 1, '56': 2, '57': 1, '61': 1},
#  '225': {'0': 2, '226': 1, '330': 1, '36': 2, '79': 1, '81': 2},
#  '226': {'0': 1, '225': 1, '79': 1},
#  '227': {'228': 1, '229': 1},
#  '228': {'227': 1, '229': 1},
#  '229': {'227': 1, '228': 1, '30': 1, '430': 1},
#  '23': {'22': 1, '24': 1, '25': 1, '26': 1},
#  '230': {'22': 1},
#  '231': {'131': 1, '183': 1, '232': 1, '289': 2, '56': 4, '677': 1},
#  '232': {'231': 1, '56': 1},
#  '233': {'22': 1, '234': 1, '235': 1, '236': 1},
#  '234': {'22': 1, '233': 1, '235': 1, '236': 1},
#  '235': {'22': 1, '233': 1, '234': 1, '236': 1},
#  '236': {'22': 1, '233': 1, '234': 1, '235': 1},
#  '237': {'238': 1, '239': 1, '28': 1, '30': 1},
#  '238': {'237': 1, '239': 1, '28': 1, '30': 1},
#  '239': {'237': 1, '238': 1, '28': 1, '30': 1},
#  '24': {'22': 1, '23': 1, '25': 1, '26': 1},
#  '240': {},
#  '241': {'13': 1, '14': 1, '242': 1},
#  '242': {'13': 1, '14': 1, '241': 1},
#  '243': {'0': 1},
#  '244': {'0': 1, '16': 1, '27': 1, '70': 1},
#  '245': {'0': 1},
#  '246': {'0': 1,
#   '125': 1,
#   '17': 2,
#   '30': 1,
#   '36': 4,
#   '37': 1,
#   '512': 1,
#   '518': 1,
#   '519': 1,
#   '81': 1},
#  '247': {'29': 1},
#  '248': {'0': 2, '109': 1, '18': 1, '214': 1, '346': 1, '8': 2},
#  '249': {'22': 1, '250': 1, '251': 1, '252': 1},
#  '25': {'22': 1, '23': 1, '24': 1, '26': 1},
#  '250': {'22': 1, '249': 1, '251': 1, '252': 1},
#  '251': {'22': 1, '249': 1, '250': 1, '252': 1},
#  '252': {'22': 1, '249': 1, '250': 1, '251': 1},
#  '253': {'28': 1, '30': 1},
#  '254': {'126': 1, '255': 1, '256': 1},
#  '255': {'126': 1, '254': 1, '256': 1},
#  '256': {'126': 1, '254': 1, '255': 1},
#  '257': {'13': 1, '320': 1, '342': 1, '36': 1, '41': 1, '416': 1, '59': 1},
#  '258': {'114': 1, '259': 1, '36': 1, '56': 1, '640': 2},
#  '259': {'258': 1, '56': 1},
#  '26': {'22': 1, '23': 1, '24': 1, '25': 1},
#  '260': {'261': 1, '36': 2, '612': 1},
#  '261': {'260': 1, '36': 1},
#  '262': {'0': 1, '114': 1, '345': 1, '36': 1, '472': 1, '473': 1, '643': 1},
#  '263': {'264': 1, '75': 1},
#  '264': {'263': 1, '75': 1},
#  '265': {'266': 1, '36': 1},
#  '266': {'265': 1, '36': 1},
#  '267': {'268': 1, '476': 1},
#  '268': {'267': 1},
#  '269': {'18': 1},
#  '27': {'0': 1,
#   '16': 1,
#   '163': 1,
#   '164': 1,
#   '183': 1,
#   '244': 1,
#   '28': 1,
#   '29': 1,
#   '290': 1,
#   '317': 1,
#   '379': 1,
#   '380': 1,
#   '42': 1,
#   '452': 1,
#   '453': 1,
#   '454': 1,
#   '506': 1,
#   '54': 1,
#   '56': 1,
#   '60': 1,
#   '70': 2,
#   '81': 1},
#  '270': {'70': 1},
#  '271': {'30': 2, '434': 1, '435': 1},
#  '272': {'144': 1},
#  '273': {'274': 1},
#  '274': {'273': 1},
#  '275': {'90': 1},
#  '276': {'162': 1, '195': 1, '36': 1},
#  '277': {'22': 1},
#  '278': {'279': 1, '280': 1, '30': 1, '70': 1},
#  '279': {'278': 1, '280': 1, '30': 1},
#  '28': {'216': 1,
#   '217': 1,
#   '218': 1,
#   '237': 1,
#   '238': 1,
#   '239': 1,
#   '253': 1,
#   '27': 1,
#   '29': 1,
#   '30': 3,
#   '323': 1,
#   '586': 1,
#   '587': 1,
#   '588': 1,
#   '589': 1},
#  '280': {'278': 1, '279': 1, '30': 1},
#  '281': {'193': 1, '205': 1, '282': 1, '59': 1},
#  '282': {'193': 1, '205': 1, '281': 1, '59': 1},
#  '283': {'284': 1, '57': 1},
#  '284': {'283': 1, '57': 1},
#  '285': {'201': 1, '286': 1, '287': 1, '443': 1, '56': 2},
#  '286': {'285': 1, '287': 1, '56': 1},
#  '287': {'285': 1, '286': 1, '56': 1},
#  '288': {'193': 1},
#  '289': {'231': 2, '56': 2},
#  '29': {'247': 1, '27': 1, '28': 1},
#  '290': {'117': 1, '27': 1, '291': 1, '292': 1, '454': 1, '70': 3, '81': 2},
#  '291': {'290': 1, '292': 1, '70': 1, '81': 1},
#  '292': {'290': 1, '291': 1, '70': 1, '81': 1},
#  '293': {'56': 1, '63': 1, '666': 1, '667': 1},
#  '294': {'22': 2, '295': 2, '296': 1, '549': 1},
#  '295': {'110': 1,
#   '22': 5,
#   '294': 2,
#   '296': 1,
#   '314': 1,
#   '343': 1,
#   '445': 1,
#   '549': 1},
#  '296': {'22': 1, '294': 1, '295': 1},
#  '297': {'0': 1, '56': 1},
#  '298': {'109': 1, '22': 1, '299': 1},
#  '299': {'109': 1, '22': 1, '298': 1},
#  '3': {'0': 1,
#   '16': 3,
#   '222': 1,
#   '344': 2,
#   '362': 1,
#   '4': 1,
#   '460': 2,
#   '5': 1,
#   '542': 1,
#   '561': 1,
#   '562': 1,
#   '6': 1,
#   '7': 1},
#  '30': {'0': 1,
#   '105': 1,
#   '106': 1,
#   '154': 1,
#   '155': 1,
#   '160': 2,
#   '161': 1,
#   '203': 1,
#   '216': 1,
#   '217': 1,
#   '218': 1,
#   '22': 4,
#   '229': 1,
#   '237': 1,
#   '238': 1,
#   '239': 1,
#   '246': 1,
#   '253': 1,
#   '271': 2,
#   '278': 1,
#   '279': 1,
#   '28': 3,
#   '280': 1,
#   '300': 1,
#   '301': 2,
#   '31': 1,
#   '356': 1,
#   '357': 1,
#   '358': 1,
#   '367': 1,
#   '37': 1,
#   '395': 1,
#   '396': 1,
#   '397': 1,
#   '40': 2,
#   '402': 1,
#   '403': 1,
#   '404': 1,
#   '412': 1,
#   '413': 1,
#   '414': 1,
#   '415': 1,
#   '417': 1,
#   '430': 1,
#   '434': 1,
#   '435': 1,
#   '457': 1,
#   '458': 1,
#   '459': 1,
#   '469': 1,
#   '470': 1,
#   '471': 1,
#   '49': 2,
#   '51': 2,
#   '512': 1,
#   '518': 1,
#   '519': 1,
#   '522': 1,
#   '523': 1,
#   '524': 1,
#   '531': 1,
#   '567': 1,
#   '568': 1,
#   '59': 1,
#   '600': 1,
#   '618': 1,
#   '619': 1,
#   '655': 1,
#   '656': 1,
#   '687': 1,
#   '81': 1,
#   '91': 1,
#   '92': 1,
#   '93': 1,
#   '94': 1},
#  '300': {'30': 1, '301': 1},
#  '301': {'30': 2, '300': 1, '402': 1, '403': 1, '404': 1},
#  '302': {},
#  '303': {'304': 1, '305': 1},
#  '304': {'303': 1, '305': 1},
#  '305': {'303': 1, '304': 1},
#  '306': {'307': 1, '308': 1, '36': 1},
#  '307': {'306': 1, '308': 1, '36': 2, '37': 1, '373': 1},
#  '308': {'306': 1, '307': 1, '36': 1},
#  '309': {'13': 1, '310': 1, '85': 1},
#  '31': {'30': 1},
#  '310': {'13': 3,
#   '14': 1,
#   '309': 1,
#   '41': 1,
#   '554': 1,
#   '644': 1,
#   '645': 1,
#   '85': 1,
#   '86': 1},
#  '311': {'312': 1, '313': 1, '669': 1, '676': 1},
#  '312': {'136': 1, '311': 1, '313': 1, '449': 1, '450': 1, '451': 1},
#  '313': {'311': 1, '312': 1},
#  '314': {'22': 2, '295': 1},
#  '315': {'0': 1, '17': 1, '8': 1},
#  '316': {'59': 1},
#  '317': {'183': 1, '27': 1, '54': 1},
#  '318': {'114': 1,
#   '319': 1,
#   '507': 1,
#   '508': 1,
#   '525': 1,
#   '526': 1,
#   '527': 1,
#   '528': 1},
#  '319': {'318': 1},
#  '32': {'0': 1},
#  '320': {'257': 1, '36': 1},
#  '321': {'36': 1},
#  '322': {'59': 1},
#  '323': {'28': 1},
#  '324': {'120': 1, '515': 1, '54': 1, '615': 1, '616': 1},
#  '325': {'193': 1, '326': 1, '500': 1, '501': 1, '54': 1, '59': 3},
#  '326': {'325': 1, '59': 1},
#  '327': {'22': 1, '328': 1},
#  '328': {'22': 1, '327': 1},
#  '329': {'195': 1, '330': 1, '61': 1},
#  '33': {'34': 1, '35': 1, '36': 1, '9': 1},
#  '330': {'225': 1, '329': 1, '36': 2, '427': 1, '428': 1, '61': 1, '81': 1},
#  '331': {'332': 1, '333': 1, '75': 1},
#  '332': {'331': 1, '333': 1, '75': 1},
#  '333': {'331': 1, '332': 1, '75': 1},
#  '334': {'335': 1, '336': 1, '337': 1, '41': 1, '447': 1, '448': 1, '56': 1},
#  '335': {'334': 1, '336': 1, '337': 1, '56': 1},
#  '336': {'334': 1, '335': 1, '337': 1, '56': 1},
#  '337': {'334': 1, '335': 1, '336': 1, '56': 1},
#  '338': {'0': 1},
#  '339': {},
#  '34': {'33': 1, '35': 1},
#  '340': {'17': 1, '18': 1, '341': 1},
#  '341': {'17': 1, '18': 1, '340': 1},
#  '342': {'13': 2, '257': 1, '41': 1, '416': 1},
#  '343': {'22': 1, '295': 1},
#  '344': {'0': 1, '16': 2, '3': 2, '460': 1},
#  '345': {'262': 1},
#  '346': {'0': 1, '13': 1, '18': 1, '248': 1, '366': 1, '8': 1},
#  '347': {'348': 1, '349': 1, '350': 1, '36': 1},
#  '348': {'347': 1, '349': 1, '350': 1, '36': 1},
#  '349': {'347': 1, '348': 1, '350': 1, '36': 1},
#  '35': {'33': 1, '34': 1},
#  '350': {'347': 1, '348': 1, '349': 1, '36': 1},
#  '351': {'352': 1, '353': 1, '56': 1},
#  '352': {'351': 1, '353': 1, '56': 1},
#  '353': {'351': 1, '352': 1, '56': 1},
#  '354': {'17': 1, '355': 1, '59': 2},
#  '355': {'354': 1, '59': 1},
#  '356': {'30': 1, '357': 1, '358': 1},
#  '357': {'30': 1, '356': 1, '358': 1},
#  '358': {'30': 1, '356': 1, '357': 1},
#  '359': {'360': 1, '361': 1},
#  '36': {'0': 5,
#   '125': 3,
#   '126': 5,
#   '131': 1,
#   '132': 1,
#   '162': 2,
#   '17': 5,
#   '190': 1,
#   '191': 1,
#   '195': 2,
#   '219': 1,
#   '220': 2,
#   '221': 1,
#   '225': 2,
#   '246': 4,
#   '257': 1,
#   '258': 1,
#   '260': 2,
#   '261': 1,
#   '262': 1,
#   '265': 1,
#   '266': 1,
#   '276': 1,
#   '306': 1,
#   '307': 2,
#   '308': 1,
#   '320': 1,
#   '321': 1,
#   '33': 1,
#   '330': 2,
#   '347': 1,
#   '348': 1,
#   '349': 1,
#   '350': 1,
#   '37': 11,
#   '373': 1,
#   '391': 1,
#   '418': 2,
#   '419': 1,
#   '420': 1,
#   '422': 1,
#   '427': 1,
#   '428': 1,
#   '446': 1,
#   '463': 2,
#   '512': 1,
#   '516': 1,
#   '517': 1,
#   '518': 1,
#   '569': 1,
#   '570': 1,
#   '571': 1,
#   '604': 1,
#   '612': 1,
#   '640': 1,
#   '653': 1,
#   '654': 1,
#   '668': 1,
#   '79': 1,
#   '8': 3,
#   '81': 5,
#   '82': 1,
#   '9': 1,
#   '98': 1,
#   '99': 2},
#  '360': {'359': 1, '361': 1},
#  '361': {'359': 1, '360': 1},
#  '362': {'3': 1},
#  '363': {'364': 1, '56': 1},
#  '364': {'363': 1, '56': 1},
#  '365': {'202': 1},
#  '366': {'13': 1, '346': 1},
#  '367': {'30': 1},
#  '368': {'369': 1, '370': 1, '371': 1, '372': 1},
#  '369': {'368': 1, '370': 1, '371': 1, '372': 1},
#  '37': {'125': 1,
#   '16': 1,
#   '190': 1,
#   '195': 2,
#   '246': 1,
#   '30': 1,
#   '307': 1,
#   '36': 11,
#   '373': 1,
#   '390': 1,
#   '412': 1,
#   '413': 1,
#   '414': 1,
#   '481': 1,
#   '484': 1,
#   '512': 1,
#   '518': 1,
#   '605': 1,
#   '61': 7,
#   '66': 1,
#   '668': 1,
#   '96': 1,
#   '99': 1},
#  '370': {'368': 1, '369': 1, '371': 1, '372': 1},
#  '371': {'368': 1, '369': 1, '370': 1, '372': 1},
#  '372': {'368': 1, '369': 1, '370': 1, '371': 1},
#  '373': {'307': 1, '36': 1, '37': 1},
#  '374': {'13': 1, '14': 1},
#  '375': {'376': 1, '377': 1, '378': 1},
#  '376': {'375': 1, '377': 1, '378': 1},
#  '377': {'375': 1, '376': 1, '378': 1},
#  '378': {'375': 1, '376': 1, '377': 1},
#  '379': {'27': 1, '380': 1},
#  '38': {'191': 1, '39': 1, '649': 1, '650': 1, '651': 1},
#  '380': {'27': 1, '379': 1},
#  '381': {'0': 1, '117': 1, '118': 1, '382': 1, '584': 1, '585': 1, '59': 1},
#  '382': {'0': 1, '117': 1, '381': 1},
#  '383': {'384': 1},
#  '384': {'383': 1},
#  '385': {'17': 1, '18': 1, '386': 1},
#  '386': {'17': 1, '18': 1, '385': 1},
#  '387': {'0': 1, '388': 1},
#  '388': {'0': 1, '387': 1},
#  '389': {'56': 1},
#  '39': {'38': 1},
#  '390': {'37': 1, '99': 1},
#  '391': {'36': 1},
#  '392': {'0': 1, '393': 1, '394': 1},
#  '393': {'0': 1, '392': 1, '394': 1},
#  '394': {'0': 1, '392': 1, '393': 1},
#  '395': {'30': 1, '396': 1, '397': 1, '40': 1},
#  '396': {'30': 1, '395': 1, '397': 1, '40': 1},
#  '397': {'30': 1, '395': 1, '396': 1, '40': 1},
#  '398': {'202': 1, '399': 1, '97': 1},
#  '399': {'202': 1, '398': 1, '465': 1, '97': 1},
#  '4': {'3': 1, '5': 1, '6': 1, '7': 1},
#  '40': {'22': 1,
#   '30': 2,
#   '395': 1,
#   '396': 1,
#   '397': 1,
#   '41': 1,
#   '42': 1,
#   '43': 1},
#  '400': {'401': 2},
#  '401': {'400': 2},
#  '402': {'30': 1, '301': 1, '403': 1, '404': 1},
#  '403': {'30': 1, '301': 1, '402': 1, '404': 1},
#  '404': {'30': 1, '301': 1, '402': 1, '403': 1},
#  '405': {'406': 1},
#  '406': {'405': 1},
#  '407': {'408': 1},
#  '408': {'407': 1},
#  '409': {'18': 1},
#  '41': {'117': 1,
#   '13': 8,
#   '138': 1,
#   '139': 1,
#   '14': 1,
#   '140': 1,
#   '171': 1,
#   '172': 1,
#   '257': 1,
#   '310': 1,
#   '334': 1,
#   '342': 1,
#   '40': 1,
#   '416': 1,
#   '42': 1,
#   '43': 1,
#   '438': 2,
#   '447': 1,
#   '448': 1,
#   '554': 1,
#   '634': 1,
#   '657': 1,
#   '658': 1,
#   '664': 1,
#   '85': 4,
#   '86': 6,
#   '87': 1},
#  '410': {'0': 1, '109': 1, '13': 1, '411': 1, '509': 1, '659': 1, '660': 1},
#  '411': {'0': 1, '13': 1, '410': 1},
#  '412': {'30': 1, '37': 1, '413': 1, '414': 1},
#  '413': {'30': 1, '37': 1, '412': 1, '414': 1},
#  '414': {'30': 1, '37': 1, '412': 1, '413': 1},
#  '415': {'30': 1},
#  '416': {'13': 1, '257': 1, '342': 1, '41': 1},
#  '417': {'203': 1, '30': 1},
#  '418': {'17': 1, '36': 2, '419': 1, '420': 1, '569': 1, '570': 1, '571': 1},
#  '419': {'17': 1, '36': 1, '418': 1, '420': 1},
#  '42': {'27': 1, '40': 1, '41': 1, '43': 1},
#  '420': {'17': 1, '36': 1, '418': 1, '419': 1},
#  '421': {'197': 1, '70': 1},
#  '422': {'36': 1, '423': 1, '424': 1, '425': 1, '521': 1, '604': 1},
#  '423': {'422': 1, '424': 1, '425': 1, '534': 1, '535': 1, '536': 1, '537': 1},
#  '424': {'422': 1, '423': 1, '425': 1},
#  '425': {'422': 1, '423': 1, '424': 1},
#  '426': {},
#  '427': {'330': 1, '36': 1, '428': 1},
#  '428': {'330': 1, '36': 1, '427': 1},
#  '429': {'183': 1, '430': 1, '431': 1, '477': 1, '478': 1, '479': 1},
#  '43': {'40': 1, '41': 1, '42': 1},
#  '430': {'229': 1, '30': 1, '429': 1, '431': 1},
#  '431': {'429': 1, '430': 1},
#  '432': {'79': 1},
#  '433': {'0': 1, '81': 1, '88': 1},
#  '434': {'271': 1, '30': 1, '435': 1},
#  '435': {'271': 1, '30': 1, '434': 1},
#  '436': {'437': 1},
#  '437': {'436': 1},
#  '438': {'13': 1, '41': 2, '439': 1, '634': 1, '657': 1, '658': 1, '85': 1},
#  '439': {'13': 1, '438': 1},
#  '44': {'45': 1, '46': 1, '47': 1, '48': 1, '560': 1},
#  '440': {'13': 1, '441': 1, '442': 1},
#  '441': {'13': 1, '440': 1, '442': 1},
#  '442': {'13': 2, '440': 1, '441': 1, '579': 1, '580': 1},
#  '443': {'201': 1, '285': 1, '56': 1},
#  '444': {'108': 1, '22': 4, '474': 1, '475': 1, '596': 1},
#  '445': {'0': 1, '110': 1, '22': 2, '295': 1, '547': 1, '548': 1},
#  '446': {'36': 1},
#  '447': {'0': 1, '175': 1, '334': 1, '41': 1, '448': 1, '614': 1, '81': 2},
#  '448': {'334': 1, '41': 1, '447': 1},
#  '449': {'136': 1, '312': 1, '450': 1, '451': 1},
#  '45': {'44': 1, '46': 1, '47': 1, '48': 1},
#  '450': {'136': 1, '312': 1, '449': 1, '451': 1},
#  '451': {'136': 1, '312': 1, '449': 1, '450': 1},
#  '452': {'27': 1, '453': 1, '454': 1},
#  '453': {'27': 1, '452': 1, '454': 1},
#  '454': {'27': 1, '290': 1, '452': 1, '453': 1, '70': 1},
#  '455': {'128': 1, '13': 2, '456': 1, '641': 1, '642': 1},
#  '456': {'128': 1, '13': 1, '455': 1},
#  '457': {'30': 1, '458': 1, '459': 1},
#  '458': {'30': 1, '457': 1, '459': 1},
#  '459': {'30': 1, '457': 1, '458': 1},
#  '46': {'44': 1, '45': 1, '47': 1, '48': 1},
#  '460': {'0': 1, '16': 1, '3': 2, '344': 1, '542': 1},
#  '461': {'0': 1, '462': 1, '482': 1, '483': 1, '75': 1, '8': 1},
#  '462': {'461': 1, '75': 1},
#  '463': {'126': 2, '36': 2},
#  '464': {'190': 1},
#  '465': {'399': 1},
#  '466': {'61': 1},
#  '467': {'468': 1, '75': 1},
#  '468': {'467': 1, '70': 1, '75': 1},
#  '469': {'30': 1},
#  '47': {'44': 1, '45': 1, '46': 1, '48': 1},
#  '470': {'30': 1, '471': 1},
#  '471': {'30': 1, '470': 1},
#  '472': {'262': 1, '473': 1},
#  '473': {'262': 1, '472': 1},
#  '474': {'108': 1, '22': 1, '444': 1, '475': 1},
#  '475': {'108': 1, '22': 1, '444': 1, '474': 1},
#  '476': {'267': 1},
#  '477': {'183': 1, '429': 1, '478': 1, '479': 1},
#  '478': {'183': 1, '429': 1, '477': 1, '479': 1},
#  '479': {'183': 1, '429': 1, '477': 1, '478': 1},
#  '48': {'44': 1, '45': 1, '46': 1, '47': 1},
#  '480': {'142': 1},
#  '481': {'37': 1},
#  '482': {'0': 1, '461': 1, '483': 1, '8': 1},
#  '483': {'0': 1, '461': 1, '482': 1, '8': 1},
#  '484': {'16': 1, '37': 1, '61': 1, '66': 1},
#  '485': {'486': 1, '487': 1},
#  '486': {'485': 1, '487': 1},
#  '487': {'485': 1, '486': 1},
#  '488': {'139': 1, '489': 1, '490': 1},
#  '489': {'139': 1, '488': 1, '490': 1},
#  '49': {'30': 2, '50': 1, '51': 2, '52': 1, '53': 1, '531': 1},
#  '490': {'139': 1, '488': 1, '489': 1},
#  '491': {'492': 1, '493': 1, '6': 1, '78': 1},
#  '492': {'491': 1, '493': 1, '6': 1, '78': 1},
#  '493': {'491': 1, '492': 1, '6': 1, '78': 1},
#  '494': {'79': 1},
#  '495': {'13': 1,
#   '496': 1,
#   '497': 1,
#   '514': 1,
#   '606': 1,
#   '607': 1,
#   '608': 1,
#   '81': 1,
#   '91': 1},
#  '496': {'495': 1, '497': 1},
#  '497': {'495': 1, '496': 1},
#  '498': {'114': 1},
#  '499': {'22': 1},
#  '5': {'3': 1, '4': 1, '6': 1, '7': 1},
#  '50': {'49': 1, '51': 1, '52': 1, '53': 1},
#  '500': {'325': 1, '501': 1, '54': 1, '59': 1},
#  '501': {'325': 1, '500': 1, '54': 1, '59': 1},
#  '502': {'224': 1, '503': 1, '56': 1, '57': 1},
#  '503': {'224': 1, '502': 1, '56': 1, '57': 1},
#  '504': {'54': 1},
#  '505': {'0': 1, '17': 1, '18': 1, '8': 1},
#  '506': {'27': 1},
#  '507': {'114': 1, '318': 1, '508': 1},
#  '508': {'114': 1, '318': 1, '507': 1},
#  '509': {'109': 2, '410': 1, '659': 1, '660': 1},
#  '51': {'160': 1, '161': 1, '30': 2, '49': 2, '50': 1, '52': 1, '53': 1},
#  '510': {'511': 1},
#  '511': {'510': 1},
#  '512': {'246': 1, '30': 1, '36': 1, '37': 1, '518': 1, '519': 1},
#  '513': {'195': 1},
#  '514': {'495': 1},
#  '515': {'120': 1, '324': 1, '615': 1, '616': 1},
#  '516': {'0': 1, '36': 1, '517': 1},
#  '517': {'0': 1, '36': 1, '516': 1},
#  '518': {'195': 1,
#   '246': 1,
#   '30': 1,
#   '36': 1,
#   '37': 1,
#   '512': 1,
#   '519': 1,
#   '668': 1},
#  '519': {'246': 1, '30': 1, '512': 1, '518': 1},
#  '52': {'49': 1, '50': 1, '51': 1, '53': 1},
#  '520': {'0': 2, '678': 1},
#  '521': {'422': 1},
#  '522': {'30': 1, '523': 1},
#  '523': {'30': 1, '522': 1},
#  '524': {'30': 1},
#  '525': {'318': 1, '526': 1, '527': 1, '528': 1},
#  '526': {'318': 1, '525': 1, '527': 1, '528': 1},
#  '527': {'318': 1, '525': 1, '526': 1, '528': 1},
#  '528': {'318': 1, '525': 1, '526': 1, '527': 1},
#  '529': {'530': 1, '85': 1},
#  '53': {'49': 1, '50': 1, '51': 1, '52': 1},
#  '530': {'529': 1, '85': 1},
#  '531': {'30': 1, '49': 1},
#  '532': {'16': 1, '22': 1, '533': 1},
#  '533': {'16': 1, '532': 1},
#  '534': {'423': 1, '535': 1, '536': 1, '537': 1},
#  '535': {'423': 1, '534': 1, '536': 1, '537': 1},
#  '536': {'423': 1, '534': 1, '535': 1, '537': 1},
#  '537': {'423': 1, '534': 1, '535': 1, '536': 1},
#  '538': {'13': 1, '539': 1},
#  '539': {'13': 1, '538': 1},
#  '54': {'144': 1,
#   '156': 1,
#   '157': 1,
#   '158': 1,
#   '183': 1,
#   '27': 1,
#   '317': 1,
#   '324': 1,
#   '325': 1,
#   '500': 1,
#   '501': 1,
#   '504': 1,
#   '55': 1,
#   '59': 3,
#   '597': 1,
#   '598': 1,
#   '599': 1},
#  '540': {'79': 1},
#  '541': {},
#  '542': {'3': 1, '460': 1},
#  '543': {'175': 1, '544': 1},
#  '544': {'175': 1, '543': 1},
#  '545': {'117': 1, '546': 1, '56': 1, '665': 1, '79': 1, '80': 1},
#  '546': {'117': 1, '545': 1, '79': 1, '80': 1},
#  '547': {'0': 1, '445': 1, '548': 1},
#  '548': {'0': 1, '445': 1, '547': 1},
#  '549': {'22': 1, '294': 1, '295': 1},
#  '55': {'144': 1, '54': 1},
#  '550': {},
#  '551': {'17': 1, '18': 1},
#  '552': {'672': 1},
#  '553': {'201': 1, '56': 1},
#  '554': {'13': 2, '310': 1, '41': 1, '624': 1, '625': 1, '85': 1, '86': 1},
#  '555': {'556': 1, '56': 1},
#  '556': {'555': 1, '56': 1},
#  '557': {'17': 1, '18': 1, '206': 1},
#  '558': {'559': 1},
#  '559': {'558': 1},
#  '56': {'0': 2,
#   '103': 1,
#   '104': 1,
#   '131': 1,
#   '146': 1,
#   '147': 1,
#   '163': 2,
#   '164': 1,
#   '183': 1,
#   '186': 1,
#   '187': 1,
#   '191': 1,
#   '201': 4,
#   '224': 2,
#   '231': 4,
#   '232': 1,
#   '258': 1,
#   '259': 1,
#   '27': 1,
#   '285': 2,
#   '286': 1,
#   '287': 1,
#   '289': 2,
#   '293': 1,
#   '297': 1,
#   '334': 1,
#   '335': 1,
#   '336': 1,
#   '337': 1,
#   '351': 1,
#   '352': 1,
#   '353': 1,
#   '363': 1,
#   '364': 1,
#   '389': 1,
#   '443': 1,
#   '502': 1,
#   '503': 1,
#   '545': 1,
#   '553': 1,
#   '555': 1,
#   '556': 1,
#   '57': 5,
#   '575': 2,
#   '576': 1,
#   '577': 1,
#   '58': 1,
#   '61': 1,
#   '665': 1,
#   '666': 1,
#   '667': 1,
#   '677': 1,
#   '70': 1,
#   '76': 1,
#   '8': 1,
#   '88': 1},
#  '560': {'44': 1},
#  '561': {'0': 1, '3': 1, '562': 1, '563': 1, '8': 1},
#  '562': {'3': 1, '561': 1},
#  '563': {'0': 1, '561': 1, '8': 1},
#  '564': {'565': 1, '566': 1, '75': 1},
#  '565': {'564': 1, '566': 1, '75': 1},
#  '566': {'564': 1, '565': 1, '75': 1},
#  '567': {'30': 1, '568': 1},
#  '568': {'30': 1, '567': 1},
#  '569': {'36': 1, '418': 1, '570': 1, '571': 1},
#  '57': {'0': 2,
#   '17': 1,
#   '18': 1,
#   '224': 1,
#   '283': 1,
#   '284': 1,
#   '502': 1,
#   '503': 1,
#   '56': 5,
#   '575': 2,
#   '58': 1,
#   '76': 1,
#   '8': 1},
#  '570': {'36': 1, '418': 1, '569': 1, '571': 1},
#  '571': {'36': 1, '418': 1, '569': 1, '570': 1},
#  '572': {'205': 1, '573': 1, '574': 1, '59': 1},
#  '573': {'205': 1, '572': 1, '574': 1, '59': 1},
#  '574': {'205': 1, '572': 1, '573': 1, '59': 1},
#  '575': {'56': 2, '57': 2},
#  '576': {'201': 1, '56': 1, '577': 1},
#  '577': {'201': 1, '56': 1, '576': 1},
#  '578': {'13': 1},
#  '579': {'13': 1, '442': 1, '580': 1},
#  '58': {'56': 1, '57': 1},
#  '580': {'13': 1, '442': 1, '579': 1},
#  '581': {'22': 1, '582': 1, '583': 1},
#  '582': {'22': 1, '581': 1, '583': 1},
#  '583': {'22': 1, '581': 1, '582': 1},
#  '584': {'118': 1, '381': 1, '585': 1, '59': 1},
#  '585': {'118': 1, '381': 1, '584': 1, '59': 1},
#  '586': {'28': 1, '587': 1, '588': 1, '589': 1},
#  '587': {'28': 1, '586': 1, '588': 1, '589': 1},
#  '588': {'28': 1, '586': 1, '587': 1, '589': 1},
#  '589': {'28': 1, '586': 1, '587': 1, '588': 1},
#  '59': {'0': 1,
#   '118': 1,
#   '17': 1,
#   '193': 3,
#   '205': 3,
#   '213': 1,
#   '257': 1,
#   '281': 1,
#   '282': 1,
#   '30': 1,
#   '316': 1,
#   '322': 1,
#   '325': 3,
#   '326': 1,
#   '354': 2,
#   '355': 1,
#   '381': 1,
#   '500': 1,
#   '501': 1,
#   '54': 3,
#   '572': 1,
#   '573': 1,
#   '574': 1,
#   '584': 1,
#   '585': 1,
#   '597': 1,
#   '598': 1,
#   '599': 1,
#   '688': 1,
#   '689': 1,
#   '690': 1,
#   '691': 1},
#  '590': {'591': 1},
#  '591': {'590': 1},
#  '592': {},
#  '593': {'14': 1, '594': 1, '595': 1},
#  '594': {'14': 1, '593': 1, '595': 1},
#  '595': {'14': 1, '593': 1, '594': 1},
#  '596': {'22': 1, '444': 1},
#  '597': {'54': 1, '59': 1, '598': 1, '599': 1},
#  '598': {'54': 1, '59': 1, '597': 1, '599': 1},
#  '599': {'54': 1, '59': 1, '597': 1, '598': 1},
#  '6': {'3': 1, '4': 1, '491': 1, '492': 1, '493': 1, '5': 1, '7': 1, '78': 1},
#  '60': {'27': 1},
#  '600': {'30': 1},
#  '601': {'201': 1},
#  '602': {'195': 1, '61': 1, '95': 1},
#  '603': {'70': 1},
#  '604': {'36': 1, '422': 1},
#  '605': {'37': 1, '61': 1, '96': 1},
#  '606': {'495': 1, '607': 1, '608': 1},
#  '607': {'495': 1, '606': 1, '608': 1},
#  '608': {'495': 1, '606': 1, '607': 1},
#  '609': {'120': 1, '610': 1, '611': 1},
#  '61': {'16': 1,
#   '195': 2,
#   '224': 1,
#   '329': 1,
#   '330': 1,
#   '37': 7,
#   '466': 1,
#   '484': 1,
#   '56': 1,
#   '602': 1,
#   '605': 1,
#   '62': 1,
#   '63': 1,
#   '66': 1,
#   '95': 2,
#   '96': 2},
#  '610': {'120': 1, '609': 1, '611': 1},
#  '611': {'120': 1, '609': 1, '610': 1},
#  '612': {'260': 1, '36': 1},
#  '613': {},
#  '614': {'175': 1, '447': 1, '81': 1},
#  '615': {'120': 1, '324': 1, '515': 1, '616': 1},
#  '616': {'120': 1, '324': 1, '515': 1, '615': 1},
#  '617': {'78': 1},
#  '618': {'30': 1, '619': 1, '81': 1},
#  '619': {'30': 1, '618': 1, '81': 1},
#  '62': {'101': 1, '61': 1, '63': 1},
#  '620': {'0': 1, '8': 1},
#  '621': {'13': 1, '622': 1},
#  '622': {'13': 1, '621': 1},
#  '623': {'18': 1, '214': 1},
#  '624': {'13': 1, '554': 1, '625': 1, '85': 1},
#  '625': {'13': 1, '554': 1, '624': 1, '85': 1},
#  '626': {'144': 1},
#  '627': {'22': 1},
#  '628': {'629': 1, '79': 1},
#  '629': {'628': 1, '79': 1},
#  '63': {'293': 1, '61': 1, '62': 1},
#  '630': {'22': 1, '631': 1, '632': 1},
#  '631': {'22': 1, '630': 1, '632': 1},
#  '632': {'22': 1, '630': 1, '631': 1},
#  '633': {'183': 1},
#  '634': {'41': 1, '438': 1, '85': 1},
#  '635': {'114': 1, '18': 1, '214': 1, '636': 1},
#  '636': {'114': 1, '18': 1, '214': 1, '635': 1},
#  '637': {'114': 1},
#  '638': {'22': 1, '639': 1},
#  '639': {'22': 1, '638': 1},
#  '64': {'65': 1},
#  '640': {'114': 1, '258': 2, '36': 1},
#  '641': {'13': 1, '455': 1, '642': 1},
#  '642': {'13': 1, '455': 1, '641': 1},
#  '643': {'0': 1, '114': 1, '262': 1},
#  '644': {'13': 1, '14': 1, '310': 1, '645': 1},
#  '645': {'13': 1, '14': 1, '310': 1, '644': 1},
#  '646': {'647': 1, '648': 1},
#  '647': {'646': 1, '648': 1},
#  '648': {'646': 1, '647': 1},
#  '649': {'191': 1, '38': 1, '650': 1, '651': 1},
#  '65': {'64': 1},
#  '650': {'191': 1, '38': 1, '649': 1, '651': 1},
#  '651': {'191': 1, '38': 1, '649': 1, '650': 1},
#  '652': {'0': 1},
#  '653': {'36': 1, '654': 1},
#  '654': {'36': 1, '653': 1},
#  '655': {'30': 1, '656': 1},
#  '656': {'30': 1, '655': 1},
#  '657': {'41': 1, '438': 1, '658': 1},
#  '658': {'41': 1, '438': 1, '657': 1},
#  '659': {'109': 1, '410': 1, '509': 1, '660': 1},
#  '66': {'16': 1, '37': 1, '484': 1, '61': 1},
#  '660': {'109': 1, '410': 1, '509': 1, '659': 1},
#  '661': {'114': 1, '175': 1, '662': 1, '663': 1},
#  '662': {'114': 1, '175': 1, '661': 1, '663': 1},
#  '663': {'114': 1, '175': 1, '661': 1, '662': 1},
#  '664': {'13': 1, '41': 1},
#  '665': {'545': 1, '56': 1},
#  '666': {'293': 1, '56': 1, '667': 1},
#  '667': {'293': 1, '56': 1, '666': 1},
#  '668': {'195': 1, '36': 1, '37': 1, '518': 1},
#  '669': {'311': 1, '670': 1, '671': 1, '676': 1, '75': 1},
#  '67': {'13': 1, '14': 1, '68': 1},
#  '670': {'669': 1, '671': 1, '75': 1},
#  '671': {'669': 1, '670': 1, '75': 1},
#  '672': {'552': 1},
#  '673': {'165': 1, '22': 1, '674': 1},
#  '674': {'165': 1, '22': 1, '673': 1},
#  '675': {'197': 1, '70': 1},
#  '676': {'311': 1, '669': 1},
#  '677': {'131': 1, '183': 1, '231': 1, '56': 1},
#  '678': {'0': 1, '520': 1},
#  '679': {},
#  '68': {'13': 1, '14': 1, '67': 1},
#  '680': {'156': 1, '681': 1, '682': 1, '683': 1},
#  '681': {'156': 1, '680': 1, '682': 1, '683': 1},
#  '682': {'156': 1, '680': 1, '681': 1, '683': 1},
#  '683': {'156': 1, '680': 1, '681': 1, '682': 1},
#  '684': {'122': 1, '22': 1},
#  '685': {'17': 1, '686': 1},
#  '686': {'17': 1, '685': 1},
#  '687': {'30': 1},
#  '688': {'59': 1, '689': 1, '690': 1, '691': 1},
#  '689': {'59': 1, '688': 1, '690': 1, '691': 1},
#  '69': {},
#  '690': {'59': 1, '688': 1, '689': 1, '691': 1},
#  '691': {'59': 1, '688': 1, '689': 1, '690': 1},
#  '692': {'693': 1},
#  '693': {'692': 1},
#  '694': {'126': 1},
#  '7': {'3': 1, '4': 1, '5': 1, '6': 1},
#  '70': {'0': 1,
#   '117': 1,
#   '135': 2,
#   '136': 1,
#   '16': 1,
#   '163': 1,
#   '164': 1,
#   '197': 2,
#   '244': 1,
#   '27': 2,
#   '270': 1,
#   '278': 1,
#   '290': 3,
#   '291': 1,
#   '292': 1,
#   '421': 1,
#   '454': 1,
#   '468': 1,
#   '56': 1,
#   '603': 1,
#   '675': 1,
#   '71': 1,
#   '72': 1,
#   '73': 1,
#   '81': 2},
#  '71': {'70': 1, '72': 1, '73': 1},
#  '72': {'70': 1, '71': 1, '73': 1},
#  '73': {'70': 1, '71': 1, '72': 1},
#  '74': {'75': 1, '88': 1},
#  '75': {'117': 1,
#   '118': 1,
#   '119': 1,
#   '263': 1,
#   '264': 1,
#   '331': 1,
#   '332': 1,
#   '333': 1,
#   '461': 1,
#   '462': 1,
#   '467': 1,
#   '468': 1,
#   '564': 1,
#   '565': 1,
#   '566': 1,
#   '669': 1,
#   '670': 1,
#   '671': 1,
#   '74': 1,
#   '78': 1},
#  '76': {'0': 1, '56': 1, '57': 1, '8': 1},
#  '77': {},
#  '78': {'0': 1,
#   '1': 1,
#   '491': 1,
#   '492': 1,
#   '493': 1,
#   '6': 1,
#   '617': 1,
#   '75': 1},
#  '79': {'0': 2,
#   '117': 1,
#   '123': 1,
#   '17': 1,
#   '225': 1,
#   '226': 1,
#   '36': 1,
#   '432': 1,
#   '494': 1,
#   '540': 1,
#   '545': 1,
#   '546': 1,
#   '628': 1,
#   '629': 1,
#   '8': 1,
#   '80': 2,
#   '98': 1,
#   '99': 1},
#  '8': {'0': 17,
#   '10': 1,
#   '107': 1,
#   '108': 1,
#   '109': 1,
#   '11': 1,
#   '125': 2,
#   '126': 1,
#   '17': 9,
#   '18': 7,
#   '214': 1,
#   '248': 2,
#   '315': 1,
#   '346': 1,
#   '36': 3,
#   '461': 1,
#   '482': 1,
#   '483': 1,
#   '505': 1,
#   '56': 1,
#   '561': 1,
#   '563': 1,
#   '57': 1,
#   '620': 1,
#   '76': 1,
#   '79': 1,
#   '83': 1,
#   '84': 1,
#   '9': 1},
#  '80': {'117': 1, '545': 1, '546': 1, '79': 2},
#  '81': {'0': 4,
#   '13': 1,
#   '17': 1,
#   '175': 1,
#   '225': 2,
#   '246': 1,
#   '27': 1,
#   '290': 2,
#   '291': 1,
#   '292': 1,
#   '30': 1,
#   '330': 1,
#   '36': 5,
#   '433': 1,
#   '447': 2,
#   '495': 1,
#   '614': 1,
#   '618': 1,
#   '619': 1,
#   '70': 2,
#   '82': 1,
#   '88': 1,
#   '91': 1},
#  '82': {'36': 1, '81': 1},
#  '83': {'8': 1, '84': 1},
#  '84': {'8': 1, '83': 1},
#  '85': {'13': 5,
#   '309': 1,
#   '310': 1,
#   '41': 4,
#   '438': 1,
#   '529': 1,
#   '530': 1,
#   '554': 1,
#   '624': 1,
#   '625': 1,
#   '634': 1,
#   '86': 3,
#   '87': 1},
#  '86': {'13': 4,
#   '171': 1,
#   '172': 1,
#   '310': 1,
#   '41': 6,
#   '554': 1,
#   '85': 3,
#   '87': 1},
#  '87': {'13': 1, '41': 1, '85': 1, '86': 1},
#  '88': {'0': 1, '433': 1, '56': 1, '74': 1, '81': 1},
#  '89': {'0': 1, '190': 1, '90': 1},
#  '9': {'10': 1, '11': 1, '33': 1, '36': 1, '8': 1},
#  '90': {'0': 1, '275': 1, '89': 1},
#  '91': {'13': 1, '30': 1, '495': 1, '81': 1, '92': 1, '93': 1, '94': 1},
#  '92': {'30': 1, '91': 1, '93': 1, '94': 1},
#  '93': {'30': 1, '91': 1, '92': 1, '94': 1},
#  '94': {'30': 1, '91': 1, '92': 1, '93': 1},
#  '95': {'195': 1, '602': 1, '61': 2, '96': 1},
#  '96': {'37': 1, '605': 1, '61': 2, '95': 1},
#  '97': {'202': 1, '398': 1, '399': 1},
#  '98': {'36': 1, '79': 1, '99': 1},
#  '99': {'36': 2, '37': 1, '390': 1, '79': 1, '98': 1}}

# %%
pairs = calculate_pairs(all_tags, cooccur_dict)
for pair in pairs:
    print(pair[0], pair[1], pair[2])
# Out:
# javascript jquery 17
# html css 13
# javascript html 12
# php mysql 11
# html jquery 9
# ios swift 8
# mysql sql 7
# css jquery 7
# swift parse.com 6
# javascript node.js 6
# javascript css 6
# ios objective-c 6
# wordpress php 5
# javascript php 5
# php arrays 5
# html php 5
# c# asp.net 5
# android android-activity 5
# ios xcode 5
# wpf c# 4
# android java 4
# table php 4
# ios parse.com 4
# swift xcode 4
# android android-fragments 4
# .net c# 4
# javascript arrays 4
# algorithm java 3
# ajax php 3
# php jquery 3
# xcode parse.com 3
# node.js mongodb 3
# pointers c++ 3
# python-2.7 python 3
# linux python 3
# ios cocoa-touch 3
# javascript google-spreadsheet 3
# python-3.x python 3
# django python 3
# javascript html5 3
# wpf devexpress 2
# sql sqlite 2
# java eclipse 2
# java multithreading 2
# swing java 2
# java maven 2
# java keytool 2
# logging java 2
# javascript sorting 2
# sorting php 2
# sorting arrays 2
# database sql 2
# sql join 2
# mysqli php 2
# javascript css3 2
# css3 jquery 2
# cordova ionic-framework 2
# ios8 ios 2
# android android-intent 2
# android-intent android-activity 2
# wordpress woocommerce 2
# wordpress braintree 2
# codeigniter php 2
# php directory 2
# database php 2
# curl php 2
# php laravel-5.1 2
# php braintree 2
# woocommerce php 2
# datetime php 2
# ios phasset 2
# database mysql 2
# ruby-on-rails nested-forms 2
# swift sprite-kit 2
# ios ipad 2
# mongodb mongodb-query 2
# css responsive-design 2
# ios uiwebview 2
# node.js mongoose 2
# node.js express 2
# ruby-on-rails ruby 2
# pointers arrays 2
# session cookies 2
# android android-manifest 2
# ios iphone 2
# html table 2
# ruby-on-rails twitter-bootstrap 2
# c c++ 2
# qt c++ 2
# c++ arrays 2
# c++11 c++ 2
# html5 html5-video 2
# devexpress c# 2
# c# drop-down-menu 2
# asp.net drop-down-menu 2
# angularjs ionic 2
# javascript c# 2
# entity-framework c# 2
# c#-4.0 c# 2
# sql-server c# 2

# %%
serialize(all_tags, 'results/10_all_tags.txt')
serialize(tags_counts, 'results/10_tags_counts.txt')
serialize(cooccur_dict, 'results/10_cooccur_dict.txt')
serialize(pairs, 'results/10_pairs.txt')
# Out:
# File results/10_all_tags.txt written.
# File results/10_tags_counts.txt written.
# File results/10_cooccur_dict.txt written.
# File results/10_pairs.txt written.

# %%
p = [('javascript', 'jquery', 17), ('html', 'css', 13), ('javascript', 'html', 12), ('php', 'mysql', 11), ('html', 'jquery', 9), ('ios', 'swift', 8), ('mysql', 'sql', 7), ('css', 'jquery', 7), ('swift', 'parse.com', 6), ('javascript', 'node.js', 6), ('javascript', 'css', 6), ('ios', 'objective-c', 6), ('wordpress', 'php', 5), ('javascript', 'php', 5), ('php', 'arrays', 5), ('html', 'php', 5), ('c#', 'asp.net', 5), ('android', 'android-activity', 5), ('ios', 'xcode', 5), ('wpf', 'c#', 4), ('android', 'java', 4), ('table', 'php', 4), ('ios', 'parse.com', 4), ('swift', 'xcode', 4), ('android', 'android-fragments', 4), ('.net', 'c#', 4), ('javascript', 'arrays', 4), ('algorithm', 'java', 3), ('ajax', 'php', 3), ('php', 'jquery', 3), ('xcode', 'parse.com', 3), ('node.js', 'mongodb', 3), ('pointers', 'c++', 3), ('python-2.7', 'python', 3), ('linux', 'python', 3), ('ios', 'cocoa-touch', 3), ('javascript', 'google-spreadsheet', 3), ('python-3.x', 'python', 3), ('django', 'python', 3), ('javascript', 'html5', 3), ('wpf', 'devexpress', 2), ('sql', 'sqlite', 2), ('java', 'eclipse', 2), ('java', 'multithreading', 2), ('swing', 'java', 2), ('java', 'maven', 2), ('java', 'keytool', 2), ('logging', 'java', 2), ('javascript', 'sorting', 2), ('sorting', 'php', 2), ('sorting', 'arrays', 2), ('database', 'sql', 2), ('sql', 'join', 2), ('mysqli', 'php', 2), ('javascript', 'css3', 2), ('css3', 'jquery', 2), ('cordova', 'ionic-framework', 2), ('ios8', 'ios', 2), ('android', 'android-intent', 2), ('android-intent', 'android-activity', 2), ('wordpress', 'woocommerce', 2), ('wordpress', 'braintree', 2), ('codeigniter', 'php', 2), ('php', 'directory', 2), ('database', 'php', 2), ('curl', 'php', 2), ('php', 'laravel-5.1', 2), ('php', 'braintree', 2), ('woocommerce', 'php', 2), ('datetime', 'php', 2), ('ios', 'phasset', 2), ('database', 'mysql', 2), ('ruby-on-rails', 'nested-forms', 2), ('swift', 'sprite-kit', 2), ('ios', 'ipad', 2), ('mongodb', 'mongodb-query', 2), ('css', 'responsive-design', 2), ('ios', 'uiwebview', 2), ('node.js', 'mongoose', 2), ('node.js', 'express', 2), ('ruby-on-rails', 'ruby', 2), ('pointers', 'arrays', 2), ('session', 'cookies', 2), ('android', 'android-manifest', 2), ('ios', 'iphone', 2), ('html', 'table', 2), ('ruby-on-rails', 'twitter-bootstrap', 2), ('c', 'c++', 2), ('qt', 'c++', 2), ('c++', 'arrays', 2), ('c++11', 'c++', 2), ('html5', 'html5-video', 2), ('devexpress', 'c#', 2), ('c#', 'drop-down-menu', 2), ('asp.net', 'drop-down-menu', 2), ('angularjs', 'ionic', 2), ('javascript', 'c#', 2), ('entity-framework', 'c#', 2), ('c#-4.0', 'c#', 2), ('sql-server', 'c#', 2)]
